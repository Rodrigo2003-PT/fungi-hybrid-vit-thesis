# %%
import os
os.environ["CUBLAS_WORKSPACE_CONFIG"] = ":4096:8"
import sys
import json
import gc
import zipfile
from pathlib import Path
from typing import Dict, List
from collections import Counter

import numpy as np
import pandas as pd
import torch
from tqdm import tqdm
from numpy.random import SeedSequence

from sklearn.metrics import (
    precision_recall_fscore_support,
    balanced_accuracy_score,
    matthews_corrcoef,
    f1_score,
    roc_auc_score,
)

from google.colab import drive

drive.mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive

# %%
experiment_name = "convtok"

drive_project_path = "/content/drive/MyDrive/colab/conv_ViT"
drive_scripts_path = os.path.join(drive_project_path, "scripts")
drive_preprocessed_zip = os.path.join(drive_project_path, "preprocessed", "preprocessed_384.zip")
drive_split_indices = os.path.join(drive_project_path, "preprocessed", "split_indices.json")

exp_suffix = experiment_name
drive_output_path = os.path.join(drive_project_path, "output", exp_suffix)
drive_checkpoint_path = os.path.join(drive_project_path, "checkpoints", exp_suffix)

local_preprocessed_path = "/content/data"
local_scripts_path = "/content/scripts"
local_checkpoint_path = os.path.join("/content/checkpoints", exp_suffix)

for p in [
    local_preprocessed_path,
    local_scripts_path,
    local_checkpoint_path,
    drive_output_path,
    drive_checkpoint_path,
]:
    os.makedirs(p, exist_ok=True)

# %%
# !pip install einops
get_ipython().system(f"cp -r {drive_scripts_path}/* {local_scripts_path}/")
sys.path.insert(0, local_scripts_path)

from checkpoints import CheckpointManager, initialize_master_state
from plotting_utils import TrainingPlotter
from training_logic import ModelTrainer, determine_optimal_epochs
from training_utils import (
    NPYImageFolder,
    calculate_dataset_stats,
    create_transforms,
    calculate_class_weights,
    grouped_bootstrap_ci,
    aggregate_predictions_by_group,
    create_data_loaders,
    print_data_distribution,
    verify_data_splits,
    get_device_info,
    TransformSubset,
    create_slide_level_folds,
    validate_split_quality

)
from config import get_config, save_config
# Out:
# Requirement already satisfied: einops in /usr/local/lib/python3.12/dist-packages (0.8.2)

# %%
config = get_config(experiment_name)
save_config(config, drive_output_path)

n_iterations = int(config["n_iterations"])
n_folds = int(config["n_folds"])
base_seed = int(config["random_seed"])

checkpoint_manager = CheckpointManager(
    local_checkpoint_dir=local_checkpoint_path,
    drive_checkpoint_dir=drive_checkpoint_path,
    n_folds=n_folds,
)

plotter = TrainingPlotter(drive_output_path, dpi=300)

checkpoint_manager.cleanup_temp_files(verbose=True)
checkpoint_manager.sync_from_drive(verbose=True)

device = get_device_info()

preprocessed_dir = os.path.join(local_preprocessed_path, "preprocessed")

if not os.path.exists(preprocessed_dir):
    if not os.path.exists(drive_preprocessed_zip):
        raise FileNotFoundError(f"Preprocessed data not found at: {drive_preprocessed_zip}")
    with zipfile.ZipFile(drive_preprocessed_zip, "r") as zf:
        zf.extractall(local_preprocessed_path)
else:
    print(f"Using existing preprocessed data at: {preprocessed_dir}")

metadata: Dict = {}
metadata_path = os.path.join(preprocessed_dir, "metadata.json")
if os.path.exists(metadata_path):
    with open(metadata_path, "r") as f:
        metadata = json.load(f)
    print(f"Loaded metadata from: {os.path.basename(metadata_path)}")
else:
    print("WARNING: metadata.json not found; using minimal metadata.")
    metadata = {
        "method": "unknown",
        "bit_depth": None,
        "image_size": config.get("image_size", None),
        "n_channels": config.get("channels", 1),
    }

# Consistency checks (preserve logic)
cfg_bit = config.get("bit_depth", None)
meta_bit = metadata.get("bit_depth", None)
if cfg_bit is not None and meta_bit is not None and cfg_bit != meta_bit:
    print(f"WARNING: config bit_depth={cfg_bit} but preprocessing bit_depth={meta_bit}.")

meta_size = metadata.get("image_size", None)
cfg_size = config.get("image_size", None)
if meta_size is not None and cfg_size is not None and meta_size != cfg_size:
    print(f"WARNING: config image_size={cfg_size} but preprocessing image_size={meta_size}.")
# Out:
#   Config saved to: /content/drive/MyDrive/colab/conv_ViT/output/convtok/config_convtok.json
#   Synced: cv_iter_28_fold_1_checkpoint.pth
#   Synced: cv_iter_28_fold_2_checkpoint.pth
#   Synced: master_training_state.json
# Sync complete: 3 file(s) updated
#
# Device Information:
#   Device: cuda
#   GPU: Tesla T4
#   Memory: 15.64 GB
#   CUDA Version: 12.8
# Loaded metadata from: metadata.json

# %%
if not os.path.exists(drive_split_indices):
    raise FileNotFoundError(f"Split indices not found at: {drive_split_indices}")

with open(drive_split_indices, "r") as f:
    split_data = json.load(f)

train_base_paths = [Path(p) for p in split_data["train_base_paths"]]
test_base_paths = [Path(p) for p in split_data["test_base_paths"]]
class_names = split_data["classes"]

print("Classes:", class_names)
print("Train images:", len(train_base_paths))
print("Test images:", len(test_base_paths))

dataset = NPYImageFolder(preprocessed_dir)
num_classes = len(dataset.classes)

labels = np.array(dataset.targets)

print("Total images:", len(dataset))
print("Num classes:", num_classes)
print("Dataset classes:", dataset.classes)

npy_base_to_idx: Dict[str, int] = {}
idx_to_base: Dict[int, Path] = {}

for idx, (sample_path, target) in enumerate(dataset.samples):
    rel_npy = Path(sample_path).relative_to(preprocessed_dir)
    base_npy = rel_npy.with_suffix("")
    npy_base_to_idx[base_npy.as_posix()] = idx
    idx_to_base[idx] = Path(base_npy)

train_val_idx: List[int] = []
test_idx: List[int] = []

for base in train_base_paths:
    key = base.as_posix()
    if key not in npy_base_to_idx:
        raise RuntimeError(f"Train base path not found in dataset mapping: {key}")
    train_val_idx.append(npy_base_to_idx[key])

for base in test_base_paths:
    key = base.as_posix()
    if key not in npy_base_to_idx:
        raise RuntimeError(f"Test base path not found in dataset mapping: {key}")
    test_idx.append(npy_base_to_idx[key])

print("TrainVal indices:", len(train_val_idx))
print("Test indices:", len(test_idx))

verify_data_splits(train_val_idx, [], test_idx)
print_data_distribution(labels[train_val_idx].tolist(), dataset.classes, "TrainVal")
print_data_distribution(labels[test_idx].tolist(), dataset.classes, "Test")
# Out:
# Classes: ['Candida albicans', 'Candida glabrata']
# Train images: 2910
# Test images: 821
# NPYImageFolder initialized: 3763 samples (grayscale)
# Total images: 3763
# Num classes: 2
# Dataset classes: ['Candida albicans', 'Candida glabrata']
# TrainVal indices: 2910
# Test indices: 821
# ✓ Data splits verified: No overlap detected
#
# TrainVal Distribution:
#   Total samples: 2910
#   Candida albicans: 1616 (55.5%)
#   Candida glabrata: 1294 (44.5%)
#
# Test Distribution:
#   Total samples: 821
#   Candida albicans: 440 (53.6%)
#   Candida glabrata: 381 (46.4%)

# %%
def extract_slide_id_from_base(p: Path) -> str:
    stem = p.name
    parts = stem.split("_")
    if len(parts) < 3:
        return stem
    date, species_code, letter = parts[0], parts[1], parts[2]
    return f"{date}_{species_code}_{letter}"

all_groups = np.empty(len(dataset), dtype=object)
for idx in range(len(dataset)):
    base_path = idx_to_base[idx]
    slide_id = extract_slide_id_from_base(base_path)
    all_groups[idx] = slide_id

test_groups = all_groups[test_idx]

def run_cross_validation(master_state: Dict) -> None:

    print("-" * 70)
    print("PHASE: CROSS-VALIDATION")
    print("-" * 70)
    print(f"Base seed: {base_seed}")

    start_iteration = int(master_state.get("current_iteration", 0))
    start_fold = int(master_state.get("current_fold", 0))
    cv_fold_details = list(master_state.get("cv_fold_details", []))

    trainer = ModelTrainer(config, device, checkpoint_manager, num_classes)

    ss = SeedSequence(base_seed)
    iteration_seed_gens = ss.spawn(n_iterations)
    iteration_seeds_base = [int(g.generate_state(1)[0]) for g in iteration_seed_gens]

    trainval_idx_np = np.array(train_val_idx)

    for iter_idx in range(start_iteration, n_iterations):
        iteration_seed_base = iteration_seeds_base[iter_idx]
        print("\n" + "=" * 70)
        print(f"ITERATION {iter_idx + 1}/{n_iterations} | base seed {iteration_seed_base}")
        print("=" * 70)

        min_slides_per_class = config.get("min_slides_per_class_validation", 2)
        min_slide_balance_ratio = config.get("min_slide_balance_ratio", 0.4)
        max_image_imbalance_ratio = config.get("max_image_imbalance_ratio", 0.2)

        try:
            fold_splits, split_metadata = create_slide_level_folds(
                image_indices=trainval_idx_np,
                image_labels=labels,
                slide_groups=all_groups,
                n_splits=n_folds,
                random_state=iteration_seed_base,
                class_names=dataset.classes,
                min_slides_per_class=min_slides_per_class,
                min_slide_balance_ratio=min_slide_balance_ratio,
                max_image_imbalance_ratio=max_image_imbalance_ratio,
                max_retries=50,
                verbose=True
            )

            iteration_seed_effective = split_metadata['random_state_effective']
            retry_count = split_metadata['retry_count']

            print(f"  Effective seed: {iteration_seed_effective}")
            if retry_count > 0:
                print(f"  Required {retry_count} {'retry' if retry_count == 1 else 'retries'}")

        except RuntimeError as e:
            print(f"\n FATAL ERROR: Could not create valid slide-stratified folds")
            print(f"\n{e}")
            print(f"\nAborting iteration {iter_idx + 1}. Please review dataset and constraints.")

            master_state["current_iteration"] = iter_idx
            master_state["current_fold"] = 0
            master_state["split_error"] = str(e)
            checkpoint_manager.save_master_state(master_state, backup_to_drive=True)
            return

        if "split_metadata_per_iteration" not in master_state:
            master_state["split_metadata_per_iteration"] = {}

        master_state["split_metadata_per_iteration"][iter_idx] = {
            "iteration_seed_base": int(iteration_seed_base),
            "iteration_seed_effective": int(iteration_seed_effective),
            "retry_count": int(retry_count),
            "n_folds": n_folds,
            "min_slides_per_class": min_slides_per_class,
            "min_slide_balance_ratio": min_slide_balance_ratio,
            "fold_quality_stats": [
                {
                    'fold_idx': meta['fold_idx'],
                    'val_n_slides': meta['val_stats']['n_slides'],
                    'val_n_images': meta['val_stats']['n_images'],
                    'val_slide_balance': meta['val_stats']['slide_balance_ratio'],
                    'val_image_balance': meta['val_stats']['image_balance_ratio'],
                    'val_slides_per_class': meta['val_stats']['slides_per_class']
                }
                for meta in split_metadata['fold_metadata']
            ]
        }

        for fold_idx, (cv_train_global, cv_val_global) in enumerate(fold_splits):
            if iter_idx == start_iteration and fold_idx < start_fold:
                continue

            print(f"Fold {fold_idx + 1}/{n_folds}")

            # Get fold statistics from metadata
            fold_meta = split_metadata['fold_metadata'][fold_idx]
            train_stats = fold_meta['train_stats']
            val_stats = fold_meta['val_stats']

            # Quality assurance check
            is_valid, error_msg = validate_split_quality(
                train_stats, val_stats, dataset.classes,
                min_slides_per_class, min_slide_balance_ratio, max_image_imbalance_ratio
            )

            if not is_valid:
                raise RuntimeError(
                    f"Split validation failed for Iter {iter_idx+1} Fold {fold_idx+1}.\n"
                    f"This indicates a bug in create_slide_level_folds.\n"
                    f"Error: {error_msg}"
                )

            print(f"\nCalculating normalization statistics from training set...")
            fold_mean, fold_std = calculate_dataset_stats(
                dataset=dataset,
                indices=cv_train_global.tolist(),
                batch_size=int(config["batch_size"]),
                num_workers=int(config["num_workers"]),
            )
            print(f"  Mean: {[f'{x:.4f}' for x in fold_mean]}")
            print(f"  Std:  {[f'{x:.4f}' for x in fold_std]}")

            # Create data loaders
            train_transform = create_transforms(fold_mean, fold_std, config, train=True)
            val_transform = create_transforms(fold_mean, fold_std, config, train=False)

            train_loader, val_loader = create_data_loaders(
                dataset=dataset,
                train_indices=cv_train_global.tolist(),
                val_indices=cv_val_global.tolist(),
                train_transform=train_transform,
                val_transform=val_transform,
                batch_size=int(config["batch_size"]),
                num_workers=int(config["num_workers"]),
            )

            fold_class_weights = calculate_class_weights(
                targets=labels[cv_train_global].tolist(),
                num_classes=num_classes,
                device=device,
                gamma=float(config.get("class_weight_gamma", 1.0)),
            )

            val_groups_fold = all_groups[cv_val_global]

            if val_groups_fold is None or len(val_groups_fold) == 0:
                raise RuntimeError(
                    f"No slide groups found for validation fold {fold_idx+1}. "
                )

            print(f"\nTraining fold {fold_idx + 1}...")
            fold_summary = trainer.train_cv_fold(
                iter_idx=iter_idx,
                fold_idx=fold_idx,
                iteration_seed=int(iteration_seed_effective),
                train_loader=train_loader,
                val_loader=val_loader,
                fold_mean=fold_mean,
                fold_std=fold_std,
                class_weights=fold_class_weights,
                val_groups_fold=val_groups_fold,
            )

            fold_summary["iteration_seed_base"] = int(iteration_seed_base)
            fold_summary["iteration_seed_effective"] = int(iteration_seed_effective)
            fold_summary["split_retry_count"] = int(retry_count)
            fold_summary["val_slides_per_class"] = val_stats['slides_per_class']
            fold_summary["val_slide_balance_ratio"] = val_stats['slide_balance_ratio']
            fold_summary["val_image_balance_ratio"] = val_stats['image_balance_ratio']

            cv_fold_details.append(fold_summary)

            master_state["cv_fold_details"] = cv_fold_details
            master_state["current_iteration"] = iter_idx
            master_state["current_fold"] = fold_idx + 1

            if fold_idx + 1 >= n_folds:
                master_state["current_iteration"] = iter_idx + 1
                master_state["current_fold"] = 0

            checkpoint_manager.save_master_state(master_state, backup_to_drive=True)
            checkpoint_manager.cleanup_previous_fold_checkpoint(iter_idx, fold_idx, verbose=True)

            del train_loader, val_loader, fold_class_weights
            gc.collect()
            if torch.cuda.is_available():
                torch.cuda.empty_cache()

        start_fold = 0

    master_state["all_iterations_completed"] = True
    master_state["phase"] = "analysis"
    checkpoint_manager.save_master_state(master_state, backup_to_drive=True)

    print("\n" + "=" * 70)
    print("CROSS-VALIDATION COMPLETE")
    print("=" * 70)
    print(f"\nCompleted {n_iterations} iterations × {n_folds} folds")
    print(f"Total fold summaries: {len(cv_fold_details)}")
    print(f"\nNext phase: Analysis")
    print("=" * 70 + "\n")

# %%
def run_analysis(master_state: Dict) -> None:

    cv_fold_details = master_state.get("cv_fold_details", [])
    if not cv_fold_details:
        print("ERROR: No CV fold details found in master_state.")
        return

    cv_results_df = pd.DataFrame(cv_fold_details)
    n_folds_total = len(cv_results_df)
    n_iters_found = cv_results_df["iteration"].nunique() if "iteration" in cv_results_df.columns else None
    print(f"Loaded {n_folds_total} fold summaries | iterations={n_iters_found}")

    # Save CSV locally + backup to Drive
    results_csv_path = checkpoint_manager.get_results_csv_path(config["experiment_name"], use_local=True)
    cv_results_df.to_csv(results_csv_path, index=False)
    print(f"CV results saved to: {results_csv_path}")

    drive_csv_path = checkpoint_manager.get_results_csv_path(config["experiment_name"], use_local=False)
    try:
        import shutil

        shutil.copy2(results_csv_path, drive_csv_path)
        print(f"Backed up to Drive: {drive_csv_path}")
    except Exception as e:
        print(f"WARNING: Could not backup CSV to Drive: {e}")

    plotter.plot_iteration_results(
        cv_results_df,
        experiment_name=config["experiment_name"],
        save_name=f"cv_iteration_results_{config['experiment_name']}.png",
        show=False,
        prefer_slide_level=True,
    )

    print("Determining optimal number of epochs...")
    optimal_epochs = determine_optimal_epochs(
        cv_fold_details=cv_results_df.to_dict("records"),
        method="median",
        config=config,
    )
    print("Selected optimal_epochs:", optimal_epochs)

    master_state["optimal_epochs"] = int(optimal_epochs)

    checkpoint_manager.cleanup_all_fold_checkpoints(verbose=True)
    master_state["phase"] = "final_training"
    checkpoint_manager.save_master_state(master_state, backup_to_drive=True)

# %%
def run_final_training(master_state: Dict) -> None:
    print("-" * 70)
    print("PHASE: FINAL TRAINING")
    print("-" * 70)

    optimal_epochs = int(master_state.get("optimal_epochs", config.get("num_epochs", 50)))
    print(f"Training final model for {optimal_epochs} epochs")

    print("Calculating normalization statistics on full training set...")
    final_mean, final_std = calculate_dataset_stats(
        dataset=dataset,
        indices=train_val_idx,
        batch_size=int(config["batch_size"]),
        num_workers=int(config["num_workers"]),
    )
    print("Final mean:", final_mean)
    print("Final std:", final_std)

    train_transform = create_transforms(final_mean, final_std, config, train=True)
    final_dataset = TransformSubset(dataset, list(train_val_idx), train_transform)

    final_loader = torch.utils.data.DataLoader(
        final_dataset,
        batch_size=int(config["batch_size"]),
        shuffle=True,
        num_workers=int(config["num_workers"]),
        pin_memory=True,
    )

    final_class_weights = calculate_class_weights(
        targets=labels[train_val_idx],
        num_classes=num_classes,
        device=device,
        gamma=float(config.get("class_weight_gamma", 1.0)),
    )

    trainer = ModelTrainer(config, device, checkpoint_manager, num_classes)
    final_model, final_training_history = trainer.train_final_model(
        train_loader=final_loader,
        optimal_epochs=optimal_epochs,
        final_mean=final_mean,
        final_std=final_std,
        class_weights=final_class_weights,
    )

    from training_logic import create_model_arch_metadata

    final_model_save_path = os.path.join(drive_output_path, f"final_model_{config['experiment_name']}.pth")
    torch.save(
        {
            "model_state_dict": final_model.state_dict(),
            "config": config,
            "mean": final_mean,
            "std": final_std,
            "class_to_idx": dataset.class_to_idx,
            "optimal_epochs": int(optimal_epochs),
            "training_history": final_training_history,
            "metadata": metadata,
            "arch_metadata": create_model_arch_metadata(config),
        },
        final_model_save_path,
    )
    print(f"Final model saved to: {final_model_save_path}")

    plotter.plot_training_curves(
        final_training_history,
        title=f"Final Model Training - {config['experiment_name']}",
        save_name=f"final_model_training_curves_{config['experiment_name']}.png",
        show=False,
    )

    master_state["final_training_completed"] = True
    master_state["phase"] = "evaluation"
    checkpoint_manager.save_master_state(master_state, backup_to_drive=True)

    print("-" * 70)
    print("FINAL TRAINING COMPLETE")
    print("-" * 70)

# %%
def run_evaluation(master_state: Dict) -> None:
    """
    Evaluate final model on held-out test set with proper slide-level aggregation.
    """
    print("\n" + "="*70)
    print("PHASE: TEST SET EVALUATION")
    print("="*70 + "\n")

    # Load final model
    final_model_path = os.path.join(
        drive_output_path,
        f"final_model_{config['experiment_name']}.pth"
    )

    if not os.path.exists(final_model_path):
        print(f"ERROR: Final model not found at {final_model_path}")
        return

    print(f"  Loading final model from {os.path.basename(final_model_path)}")
    checkpoint = torch.load(final_model_path, map_location=device)

    # Create model
    from convViT import SimpleViT_ConvTok

    model = SimpleViT_ConvTok(
        image_size=config["image_size"],
        num_classes=num_classes,
        dim=config["model_config"]["dim"],
        depth=config["model_config"]["depth"],
        heads=config["model_config"]["heads"],
        mlp_dim=config["model_config"]["mlp_dim"],
        channels=config["channels"],
        dim_head=config["model_config"].get("dim_head", 64),
        convtok_hidden_channels=config.get("convtok_hidden_channels", 64),
        convtok_blocks=config.get("convtok_blocks"),
        convtok_match_baseline_tokens=config.get("convtok_match_baseline_tokens", True),
        convtok_expected_hw=config.get("convtok_expected_hw", [24, 24]),
        convtok_conv_bias=config.get("convtok_conv_bias", False),
        init_policy=config.get("init_policy", "default"),
        pe_temperature=config["model_config"].get("pe_temperature", 10000),
    ).to(device)

    from training_logic import validate_checkpoint_arch
    validate_checkpoint_arch(checkpoint, config, strict=True)
    model.load_state_dict(checkpoint["model_state_dict"])
    model.eval()
    print("  Model loaded successfully")

    # Create test loader
    test_mean = checkpoint["mean"]
    test_std = checkpoint["std"]
    test_transform = create_transforms(test_mean, test_std, config, train=False)

    _, test_loader = create_data_loaders(
        dataset,
        train_indices=[],
        val_indices=test_idx,
        train_transform=None,
        val_transform=test_transform,
        batch_size=config["batch_size"],
        num_workers=config["num_workers"],
    )

    # Run inference
    all_preds = []
    all_labels = []
    all_probs_list = []

    print(f"  Running inference on {len(test_idx)} test samples...")
    with torch.inference_mode():
        for X, y in tqdm(test_loader, desc="Testing", ncols=80, leave=False):
            X = X.to(device)
            logits = model(X)
            probs = logits.softmax(dim=1)
            all_preds.extend(logits.argmax(1).cpu().numpy())
            all_probs_list.append(probs.cpu().numpy())
            all_labels.extend(y.cpu().numpy())
    print("  Inference complete")

    all_preds = np.array(all_preds)
    all_labels = np.array(all_labels)
    all_probs = np.vstack(all_probs_list)

    # ------------------------------------------------------------------
    # 1) IMAGE-LEVEL METRICS (Patch-based)
    # ------------------------------------------------------------------
    print("\n  Computing image-level metrics...")
    test_bal_acc = balanced_accuracy_score(all_labels, all_preds)
    test_mcc = matthews_corrcoef(all_labels, all_preds)
    test_f1 = f1_score(all_labels, all_preds, average="weighted", zero_division=0)
    test_auc = roc_auc_score(all_labels, all_probs[:, 1])

    print("  Calculating 95% confidence intervals (1000 bootstrap) - image level...")
    bal_acc_ci = grouped_bootstrap_ci(
        balanced_accuracy_score,
        [all_labels, all_preds],
        groups=test_groups,
        n_bootstrap=1000,
        ci=0.95,
        seed=42,
        verbose=False,
    )
    mcc_ci = grouped_bootstrap_ci(
        matthews_corrcoef,
        [all_labels, all_preds],
        groups=test_groups,
        n_bootstrap=1000,
        ci=0.95,
        seed=43,
        verbose=False,
    )
    f1_ci = grouped_bootstrap_ci(
        lambda y_true, y_pred: f1_score(y_true, y_pred, average="weighted", zero_division=0),
        [all_labels, all_preds],
        groups=test_groups,
        n_bootstrap=1000,
        ci=0.95,
        seed=44,
        verbose=False,
    )
    auc_ci = grouped_bootstrap_ci(
        lambda y_true, p_hat: roc_auc_score(y_true, p_hat[:, 1]),
        [all_labels, all_probs],
        groups=test_groups,
        n_bootstrap=1000,
        ci=0.95,
        seed=45,
        verbose=False,
    )

    # ------------------------------------------------------------------
    # 2) SLIDE-LEVEL AGGREGATION AND METRICS
    # ------------------------------------------------------------------
    print("\n  Aggregating predictions to slide level...")
    (
        slide_true,
        slide_pred,
        slide_proba,
        slide_ids,
    ) = aggregate_predictions_by_group(
        y_true=all_labels,
        y_pred=all_preds,
        y_proba=all_probs,
        groups=test_groups,
        num_classes=num_classes,
    )

    print(f"  Aggregated {len(all_labels)} images into {len(slide_true)} slides")

    # Slide-level metrics
    slide_bal_acc = balanced_accuracy_score(slide_true, slide_pred)
    slide_mcc = matthews_corrcoef(slide_true, slide_pred)
    slide_f1 = f1_score(slide_true, slide_pred, average="weighted", zero_division=0)
    slide_auc = roc_auc_score(slide_true, slide_proba[:, 1])

    print("  Calculating 95% confidence intervals (1000 bootstrap) - slide level...")
    slide_groups_dummy = np.arange(len(slide_true))  # Each slide is its own group

    slide_bal_acc_ci = grouped_bootstrap_ci(
        balanced_accuracy_score,
        [slide_true, slide_pred],
        groups=slide_groups_dummy,
        n_bootstrap=1000,
        ci=0.95,
        seed=52,
        verbose=False,
    )
    slide_mcc_ci = grouped_bootstrap_ci(
        matthews_corrcoef,
        [slide_true, slide_pred],
        groups=slide_groups_dummy,
        n_bootstrap=1000,
        ci=0.95,
        seed=53,
        verbose=False,
    )
    slide_f1_ci = grouped_bootstrap_ci(
        lambda y_true, y_pred: f1_score(y_true, y_pred, average="weighted", zero_division=0),
        [slide_true, slide_pred],
        groups=slide_groups_dummy,
        n_bootstrap=1000,
        ci=0.95,
        seed=54,
        verbose=False,
    )
    slide_auc_ci = grouped_bootstrap_ci(
        lambda y_true, p_hat: roc_auc_score(y_true, p_hat[:, 1]),
        [slide_true, slide_proba],
        groups=slide_groups_dummy,
        n_bootstrap=1000,
        ci=0.95,
        seed=55,
        verbose=False,
    )

    # ------------------------------------------------------------------
    # 3) PER-CLASS METRICS (Both levels)
    # ------------------------------------------------------------------
    print("\n  Computing per-class metrics...")

    # Image-level per-class
    p_img, r_img, f1_img, s_img = precision_recall_fscore_support(
        all_labels,
        all_preds,
        labels=list(range(num_classes)),
        average=None,
        zero_division=0,
    )

    per_class_metrics_image = {}
    for i, class_name in enumerate(dataset.classes):
        per_class_metrics_image[class_name] = {
            "precision": float(p_img[i]),
            "recall": float(r_img[i]),
            "f1_score": float(f1_img[i]),
            "support": int(s_img[i]),
        }

    # Slide-level per-class
    p_slide, r_slide, f1_slide, s_slide = precision_recall_fscore_support(
        slide_true,
        slide_pred,
        labels=list(range(num_classes)),
        average=None,
        zero_division=0,
    )

    per_class_metrics_slide = {}
    for i, class_name in enumerate(dataset.classes):
        per_class_metrics_slide[class_name] = {
            "precision": float(p_slide[i]),
            "recall": float(r_slide[i]),
            "f1_score": float(f1_slide[i]),
            "support": int(s_slide[i]),
        }

    # ------------------------------------------------------------------
    # 4) PRINT SUMMARY
    # ------------------------------------------------------------------
    print("\n" + "="*70)
    print("TEST SET RESULTS SUMMARY")
    print("="*70)

    print("\nIMAGE-LEVEL METRICS (Patch-based):")
    print(f"  Balanced Accuracy: {test_bal_acc:.4f} (95% CI: [{bal_acc_ci[0]:.4f}, {bal_acc_ci[1]:.4f}])")
    print(f"  MCC:               {test_mcc:.4f} (95% CI: [{mcc_ci[0]:.4f}, {mcc_ci[1]:.4f}])")
    print(f"  F1-Score:          {test_f1:.4f} (95% CI: [{f1_ci[0]:.4f}, {f1_ci[1]:.4f}])")
    print(f"  AUC:               {test_auc:.4f} (95% CI: [{auc_ci[0]:.4f}, {auc_ci[1]:.4f}])")

    print("\nSLIDE-LEVEL METRICS (Aggregated):")
    print(f"  Balanced Accuracy: {slide_bal_acc:.4f} (95% CI: [{slide_bal_acc_ci[0]:.4f}, {slide_bal_acc_ci[1]:.4f}])")
    print(f"  MCC:               {slide_mcc:.4f} (95% CI: [{slide_mcc_ci[0]:.4f}, {slide_mcc_ci[1]:.4f}])")
    print(f"  F1-Score:          {slide_f1:.4f} (95% CI: [{slide_f1_ci[0]:.4f}, {slide_f1_ci[1]:.4f}])")
    print(f"  AUC:               {slide_auc:.4f} (95% CI: [{slide_auc_ci[0]:.4f}, {slide_auc_ci[1]:.4f}])")

    print("\nPER-CLASS METRICS:")
    for class_name in dataset.classes:
        img_metrics = per_class_metrics_image[class_name]
        slide_metrics = per_class_metrics_slide[class_name]
        print(f"\n  {class_name}:")
        print(f"    Image-level: P={img_metrics['precision']:.3f}, R={img_metrics['recall']:.3f}, "
              f"F1={img_metrics['f1_score']:.3f} (n={img_metrics['support']} images)")
        print(f"    Slide-level: P={slide_metrics['precision']:.3f}, R={slide_metrics['recall']:.3f}, "
              f"F1={slide_metrics['f1_score']:.3f} (n={slide_metrics['support']} slides)")

    print("="*70 + "\n")

    # ------------------------------------------------------------------
    # 5) VISUALIZATIONS
    # ------------------------------------------------------------------
    print("  Generating visualizations...")

    # Confusion matrix (image-level)
    plotter.plot_confusion_matrix(
        all_labels,
        all_preds,
        dataset.classes,
        title="Test Set Confusion Matrix (Image-Level)",
        save_name=f"confusion_matrix_image_{config['experiment_name']}.png",
        normalize=True,
        show=False
    )

    # Confusion matrix (slide-level)
    plotter.plot_confusion_matrix(
        slide_true,
        slide_pred,
        dataset.classes,
        title="Test Set Confusion Matrix (Slide-Level)",
        save_name=f"confusion_matrix_slide_{config['experiment_name']}.png",
        normalize=True,
        show=False
    )

    # ROC curve (image-level)
    plotter.plot_roc_auc_curves(
        all_labels,
        all_probs,
        title=f"ROC Curve (Image-Level) - {config['experiment_name']}",
        save_name=f"roc_auc_curve_image_{config['experiment_name']}.png",
        show=False
    )

    # ROC curve (slide-level)
    plotter.plot_roc_auc_curves(
        slide_true,
        slide_proba,
        title=f"ROC Curve (Slide-Level) - {config['experiment_name']}",
        save_name=f"roc_auc_curve_slide_{config['experiment_name']}.png",
        show=False
    )

    # ------------------------------------------------------------------
    # 6) SAVE RESULTS
    # ------------------------------------------------------------------
    test_results_data = {
        "experiment_name": config["experiment_name"],
        "metadata": metadata,

        # Image-level metrics
        "overall_metrics_image_level": {
            "balanced_accuracy": float(test_bal_acc),
            "mcc": float(test_mcc),
            "f1_score_weighted": float(test_f1),
            "auc_binary": float(test_auc),
        },
        "confidence_intervals_95_image_level": {
            "balanced_accuracy": (float(bal_acc_ci[0]), float(bal_acc_ci[1])),
            "mcc": (float(mcc_ci[0]), float(mcc_ci[1])),
            "f1_score_weighted": (float(f1_ci[0]), float(f1_ci[1])),
            "auc_binary": (float(auc_ci[0]), float(auc_ci[1])),
        },

        # Slide-level metrics
        "overall_metrics_slide_level": {
            "balanced_accuracy": float(slide_bal_acc),
            "mcc": float(slide_mcc),
            "f1_score_weighted": float(slide_f1),
            "auc_binary": float(slide_auc),
        },
        "confidence_intervals_95_slide_level": {
            "balanced_accuracy": (float(slide_bal_acc_ci[0]), float(slide_bal_acc_ci[1])),
            "mcc": (float(slide_mcc_ci[0]), float(slide_mcc_ci[1])),
            "f1_score_weighted": (float(slide_f1_ci[0]), float(slide_f1_ci[1])),
            "auc_binary": (float(slide_auc_ci[0]), float(slide_auc_ci[1])),
        },

        # Per-class metrics
        "per_class_metrics_image_level": per_class_metrics_image,
        "per_class_metrics_slide_level": per_class_metrics_slide,

        # Dataset sizes
        "test_set_size_images": len(test_idx),
        "test_set_size_slides": int(len(np.unique(test_groups))),

        # Additional metadata
        "unique_test_slides": sorted([str(sid) for sid in np.unique(test_groups)]),
    }

    results_json_path = os.path.join(
        drive_output_path,
        f"test_results_{config['experiment_name']}.json"
    )

    with open(results_json_path, 'w') as f:
        json.dump(test_results_data, f, indent=4)

    print(f"\n  Results saved to: {os.path.basename(results_json_path)}")
    checkpoint_manager.cleanup_fold_histories(verbose=True)

    # Update master state
    master_state["phase"] = "completed"
    checkpoint_manager.save_master_state(master_state, backup_to_drive=True)

    print("\n" + "="*70)
    print("EVALUATION COMPLETE")
    print("="*70 + "\n")

# %%
def main() -> None:
    master_state = checkpoint_manager.load_master_state(prefer_drive=True)
    if master_state is None:
        print("No previous training state found. Initializing new state...")
        master_state = initialize_master_state()
        checkpoint_manager.save_master_state(master_state, backup_to_drive=True)
        print("Master state initialized")
    else:
        print(f"Resuming from saved state | phase={master_state.get('phase', 'unknown')}")

    try:
        phase = master_state.get("phase", "cross_validation")

        if phase == "cross_validation":
            run_cross_validation(master_state)
            phase = "analysis"

        if phase == "analysis":
            run_analysis(master_state)
            phase = "final_training"

        if phase == "final_training":
            run_final_training(master_state)
            phase = "evaluation"

        if phase == "evaluation":
            run_evaluation(master_state)
            phase = "completed"

        if phase == "completed":
            print("-" * 70)
            print("PIPELINE COMPLETED SUCCESSFULLY")
            print("-" * 70)
            print("Experiment:", config["experiment_name"])
            print("Results:", drive_output_path)

    except KeyboardInterrupt:
        print("Training interrupted by user.")
        print("Current phase:", master_state.get("phase", "unknown"))
        print("State saved - run again to resume.")
    except Exception as e:
        print(f"ERROR: {e}")
        import traceback

        traceback.print_exc()
        print("Current phase:", master_state.get("phase", "unknown"))
        print("State saved - fix error and run again to resume.")


if __name__ == "__main__":
    main()
# Out:
# Loaded master state from: master_training_state.json
# Resuming from saved state | phase=cross_validation
# ----------------------------------------------------------------------
# PHASE: CROSS-VALIDATION
# ----------------------------------------------------------------------
# Base seed: 42
# MixUp enabled: alpha=0.2, prob=0.5
#
# ======================================================================
# ITERATION 29/30 | base seed 168388230
# ======================================================================
#
# ✓ Valid splits found on first attempt
#   Effective seed: 168388230
# Fold 3/5
#
# Calculating normalization statistics from training set...
#   Mean: ['0.2371']
#   Std:  ['0.0073']
# Using uniform class weights (gamma=0, recommended with MixUp)
#
# Training fold 3...
#
# ======================================================================
# ITERATION 29/30 | FOLD 3/5
# Iteration Seed: 168388230
# Validation: ~10 slides, 567 patches
# Resuming from checkpoint:
#   Last completed epoch: 49
#   Next epoch to train: 50
#   Best model: epoch 43
# Model initialization seed: 2589400225
#   Model config:
#     init_policy          : default
#     dim_head             : 64
#     pe_temperature       : 10000
#     convtok_hidden_ch    : 64
#     arch_hash            : 2cbb5e7002e51df8
# [ConvTok] Analytical output grid: (24, 24) (N=576) for 384×384 input
# [ConvTok] Analytical matched-N assertion passed at construction: (24, 24) = (24, 24), N=576
#   Model created (seed=2589400225): 5,409,346 params (5,409,346 trainable)
#   [ConvTok diag] Token stats (post-ConvTok+LN, dummy batch): mean=-0.0000, std=1.0000, grid=(24,24), N=576
# Model, optimizer, scheduler, scaler, and RNG states restored
#   Restored optimizer, scheduler, and RNG states
# [ConvTok] Runtime token grid (forward #1): H'=24, W'=24, N=576
# [ConvTok] Matched-N assertion passed (forward #1): (24, 24) = (24, 24), N=576
#
#  BEST MODEL at epoch 51 (reason: tied_slide_ba_better_loss)
#    slide_BA: 1.0000 | val_loss: 0.0166
# Iter 29, Fold 3, Epoch 51/100 | train_loss: 0.0833 | train_acc: 0.8596
#   PATCH-level: val_loss=0.0166, bal_acc=0.9984
#   SLIDE-level: BA=1.0000 | EMA smoothed=0.9950
#   Best model: epoch 51, BA=1.0000, loss=0.0166
#   Best EMA smoothed: 0.9961 (epoch 32)
#   Patience: 19/20 (remaining: 1)
#   LR: 0.000158
# Iter 29, Fold 3, Epoch 52/100 | train_loss: 0.1304 | train_acc: 0.8882
#   PATCH-level: val_loss=0.1080, bal_acc=0.9590
#   SLIDE-level: BA=1.0000 | EMA smoothed=0.9965
#   Best model: epoch 51, BA=1.0000, loss=0.0166
#   Best EMA smoothed: 0.9961 (epoch 32)
#   Patience: 20/20 (remaining: 0)
#   LR: 0.000153
# Checkpoint saved: cv_iter_28_fold_2_checkpoint.pth (best_epoch=50)[hash=2cbb5e7002e51df8]
#
#  EARLY STOPPING triggered at epoch 52
#    Best model: epoch 51
#    slide_BA=1.0000,    val_loss=0.0166
#    Best EMA smoothed: 0.9961 (epoch 32)
#
# RESTORED best model weights from epoch 51
#       1. slide_BA (maximize): 1.0000
#       2. val_loss (minimize): 0.0166
#     EMA smoothed at that epoch: 0.9950
#
# Saving FINAL checkpoint and history for Iter 29 Fold 3...
# Checkpoint saved: cv_iter_28_fold_2_checkpoint.pth (best_epoch=50)[hash=2cbb5e7002e51df8]
#
# Iter 29 Fold 3 Summary (at best epoch 51):
#   SLIDE-LEVEL:
#     Balanced Acc: 1.0000
#     Val Loss:     0.0166
#     EMA smoothed: 0.9950
#     MCC: 1.0000
#     AUC: 1.0000
#   PATCH-LEVEL:
#     Balanced Acc: 0.9984
#     MCC: 0.9965
#   Training time: 54.86s
#   Cleaned local checkpoint: iter_28_fold_1
#   Cleaned Drive checkpoint: iter_28_fold_1
# Fold 4/5
#
# Calculating normalization statistics from training set...
#   Mean: ['0.2368']
#   Std:  ['0.0074']
# Using uniform class weights (gamma=0, recommended with MixUp)
#
# Training fold 4...
#
# ======================================================================
# ITERATION 29/30 | FOLD 4/5
# Iteration Seed: 168388230
# Validation: ~9 slides, 616 patches
# Starting fold from scratch
# Model initialization seed: 84200233
#   Model config:
#     init_policy          : default
#     dim_head             : 64
#     pe_temperature       : 10000
#     convtok_hidden_ch    : 64
#     arch_hash            : 2cbb5e7002e51df8
# [ConvTok] Analytical output grid: (24, 24) (N=576) for 384×384 input
# [ConvTok] Analytical matched-N assertion passed at construction: (24, 24) = (24, 24), N=576
#   Model created (seed=84200233): 5,409,346 params (5,409,346 trainable)
#   [ConvTok diag] Token stats (post-ConvTok+LN, dummy batch): mean=0.0000, std=1.0000, grid=(24,24), N=576
# [ConvTok] Runtime token grid (forward #1): H'=24, W'=24, N=576
# [ConvTok] Matched-N assertion passed (forward #1): (24, 24) = (24, 24), N=576
#
#  BEST MODEL at epoch 1 (reason: first_epoch)
#    slide_BA: 0.7000 | val_loss: 0.6550
# Iter 29, Fold 4, Epoch 1/100 | train_loss: 0.6544 | train_acc: 0.5911
#   PATCH-level: val_loss=0.6550, bal_acc=0.6122
#   SLIDE-level: BA=0.7000 | EMA smoothed=0.7000
#   Best model: epoch 1, BA=0.7000, loss=0.6550
#   Best EMA smoothed: 0.7000 (epoch 1)
#   Patience: 1/20 (remaining: 19)
#   LR: 0.000120
#
#  BEST MODEL at epoch 2 (reason: better_slide_ba)
#    slide_BA: 0.9000 | val_loss: 0.5346
# Iter 29, Fold 4, Epoch 2/100 | train_loss: 0.6454 | train_acc: 0.6308
#   PATCH-level: val_loss=0.5346, bal_acc=0.7665
#   SLIDE-level: BA=0.9000 | EMA smoothed=0.7600
#   Best model: epoch 2, BA=0.9000, loss=0.5346
#   Best EMA smoothed: 0.7600 (epoch 2)
#   Patience: 0/20 (remaining: 20)
#   LR: 0.000180
# Iter 29, Fold 4, Epoch 3/100 | train_loss: 0.5644 | train_acc: 0.7040
#   PATCH-level: val_loss=0.5317, bal_acc=0.7518
#   SLIDE-level: BA=0.8000 | EMA smoothed=0.7720
#   Best model: epoch 2, BA=0.9000, loss=0.5346
#   Best EMA smoothed: 0.7720 (epoch 3)
#   Patience: 0/20 (remaining: 20)
#   LR: 0.000240
# Iter 29, Fold 4, Epoch 4/100 | train_loss: 0.4719 | train_acc: 0.7306
#   PATCH-level: val_loss=1.3846, bal_acc=0.5699
#   SLIDE-level: BA=0.5000 | EMA smoothed=0.6904
#   Best model: epoch 2, BA=0.9000, loss=0.5346
#   Best EMA smoothed: 0.7720 (epoch 3)
#   Patience: 1/20 (remaining: 19)
#   LR: 0.000300
# Iter 29, Fold 4, Epoch 5/100 | train_loss: 0.4541 | train_acc: 0.7367
#   PATCH-level: val_loss=1.5942, bal_acc=0.5624
#   SLIDE-level: BA=0.5000 | EMA smoothed=0.6333
#   Best model: epoch 2, BA=0.9000, loss=0.5346
#   Best EMA smoothed: 0.7720 (epoch 3)
#   Patience: 2/20 (remaining: 18)
#   LR: 0.000300
#
#  BEST MODEL at epoch 6 (reason: better_slide_ba)
#    slide_BA: 1.0000 | val_loss: 0.2830
# Iter 29, Fold 4, Epoch 6/100 | train_loss: 0.3279 | train_acc: 0.7633
#   PATCH-level: val_loss=0.2830, bal_acc=0.8978
#   SLIDE-level: BA=1.0000 | EMA smoothed=0.7433
#   Best model: epoch 6, BA=1.0000, loss=0.2830
#   Best EMA smoothed: 0.7720 (epoch 3)
#   Patience: 3/20 (remaining: 17)
#   LR: 0.000300
# Iter 29, Fold 4, Epoch 7/100 | train_loss: 0.2909 | train_acc: 0.8313
#   PATCH-level: val_loss=0.5873, bal_acc=0.7594
#   SLIDE-level: BA=0.9000 | EMA smoothed=0.7903
#   Best model: epoch 6, BA=1.0000, loss=0.2830
#   Best EMA smoothed: 0.7903 (epoch 7)
#   Patience: 0/20 (remaining: 20)
#   LR: 0.000300
#
#  BEST MODEL at epoch 8 (reason: tied_slide_ba_better_loss)
#    slide_BA: 1.0000 | val_loss: 0.2268
# Iter 29, Fold 4, Epoch 8/100 | train_loss: 0.4371 | train_acc: 0.7459
#   PATCH-level: val_loss=0.2268, bal_acc=0.9235
#   SLIDE-level: BA=1.0000 | EMA smoothed=0.8532
#   Best model: epoch 8, BA=1.0000, loss=0.2268
#   Best EMA smoothed: 0.8532 (epoch 8)
#   Patience: 0/20 (remaining: 20)
#   LR: 0.000299
# Iter 29, Fold 4, Epoch 9/100 | train_loss: 0.2410 | train_acc: 0.8243
#   PATCH-level: val_loss=0.2650, bal_acc=0.9149
#   SLIDE-level: BA=1.0000 | EMA smoothed=0.8973
#   Best model: epoch 8, BA=1.0000, loss=0.2268
#   Best EMA smoothed: 0.8973 (epoch 9)
#   Patience: 0/20 (remaining: 20)
#   LR: 0.000299
# Iter 29, Fold 4, Epoch 10/100 | train_loss: 0.3221 | train_acc: 0.8217
#   PATCH-level: val_loss=0.4603, bal_acc=0.8265
#   SLIDE-level: BA=0.9000 | EMA smoothed=0.8981
#   Best model: epoch 8, BA=1.0000, loss=0.2268
#   Best EMA smoothed: 0.8973 (epoch 9)
#   Patience: 1/20 (remaining: 19)
#   LR: 0.000298
#
#  BEST MODEL at epoch 11 (reason: tied_slide_ba_better_loss)
#    slide_BA: 1.0000 | val_loss: 0.2085
# Iter 29, Fold 4, Epoch 11/100 | train_loss: 0.2000 | train_acc: 0.8561
#   PATCH-level: val_loss=0.2085, bal_acc=0.9196
#   SLIDE-level: BA=1.0000 | EMA smoothed=0.9287
#   Best model: epoch 11, BA=1.0000, loss=0.2085
#   Best EMA smoothed: 0.9287 (epoch 11)
#   Patience: 0/20 (remaining: 20)
#   LR: 0.000297
# Iter 29, Fold 4, Epoch 12/100 | train_loss: 0.3481 | train_acc: 0.7990
#   PATCH-level: val_loss=0.3848, bal_acc=0.8797
#   SLIDE-level: BA=1.0000 | EMA smoothed=0.9501
#   Best model: epoch 11, BA=1.0000, loss=0.2085
#   Best EMA smoothed: 0.9501 (epoch 12)
#   Patience: 0/20 (remaining: 20)
#   LR: 0.000296
# Iter 29, Fold 4, Epoch 13/100 | train_loss: 0.2794 | train_acc: 0.8344
#   PATCH-level: val_loss=0.2901, bal_acc=0.8959
#   SLIDE-level: BA=1.0000 | EMA smoothed=0.9650
#   Best model: epoch 11, BA=1.0000, loss=0.2085
#   Best EMA smoothed: 0.9650 (epoch 13)
#   Patience: 0/20 (remaining: 20)
#   LR: 0.000295
#
#  BEST MODEL at epoch 14 (reason: tied_slide_ba_better_loss)
#    slide_BA: 1.0000 | val_loss: 0.1725
# Iter 29, Fold 4, Epoch 14/100 | train_loss: 0.2133 | train_acc: 0.8592
#   PATCH-level: val_loss=0.1725, bal_acc=0.9363
#   SLIDE-level: BA=1.0000 | EMA smoothed=0.9755
#   Best model: epoch 14, BA=1.0000, loss=0.1725
#   Best EMA smoothed: 0.9755 (epoch 14)
#   Patience: 0/20 (remaining: 20)
#   LR: 0.000293
# Iter 29, Fold 4, Epoch 15/100 | train_loss: 0.2661 | train_acc: 0.8413
#   PATCH-level: val_loss=2.0969, bal_acc=0.5919
#   SLIDE-level: BA=0.5000 | EMA smoothed=0.8329
#   Best model: epoch 14, BA=1.0000, loss=0.1725
#   Best EMA smoothed: 0.9755 (epoch 14)
#   Patience: 1/20 (remaining: 19)
#   LR: 0.000292
# Iter 29, Fold 4, Epoch 16/100 | train_loss: 0.2952 | train_acc: 0.8522
#   PATCH-level: val_loss=0.1877, bal_acc=0.9388
#   SLIDE-level: BA=1.0000 | EMA smoothed=0.8830
#   Best model: epoch 14, BA=1.0000, loss=0.1725
#   Best EMA smoothed: 0.9755 (epoch 14)
#   Patience: 2/20 (remaining: 18)
#   LR: 0.000290
#
#  BEST MODEL at epoch 17 (reason: tied_slide_ba_better_loss)
#    slide_BA: 1.0000 | val_loss: 0.1600
# Iter 29, Fold 4, Epoch 17/100 | train_loss: 0.2772 | train_acc: 0.8561
#   PATCH-level: val_loss=0.1600, bal_acc=0.9399
#   SLIDE-level: BA=1.0000 | EMA smoothed=0.9181
#   Best model: epoch 17, BA=1.0000, loss=0.1600
#   Best EMA smoothed: 0.9755 (epoch 14)
#   Patience: 3/20 (remaining: 17)
#   LR: 0.000288
# Iter 29, Fold 4, Epoch 18/100 | train_loss: 0.2471 | train_acc: 0.8126
#   PATCH-level: val_loss=0.8165, bal_acc=0.7632
#   SLIDE-level: BA=0.9000 | EMA smoothed=0.9127
#   Best model: epoch 17, BA=1.0000, loss=0.1600
#   Best EMA smoothed: 0.9755 (epoch 14)
#   Patience: 4/20 (remaining: 16)
#   LR: 0.000286
#
#  BEST MODEL at epoch 19 (reason: tied_slide_ba_better_loss)
#    slide_BA: 1.0000 | val_loss: 0.1282
# Iter 29, Fold 4, Epoch 19/100 | train_loss: 0.2118 | train_acc: 0.8500
#   PATCH-level: val_loss=0.1282, bal_acc=0.9544
#   SLIDE-level: BA=1.0000 | EMA smoothed=0.9389
#   Best model: epoch 19, BA=1.0000, loss=0.1282
#   Best EMA smoothed: 0.9755 (epoch 14)
#   Patience: 5/20 (remaining: 15)
#   LR: 0.000284
# Iter 29, Fold 4, Epoch 20/100 | train_loss: 0.1759 | train_acc: 0.8797
#   PATCH-level: val_loss=0.8021, bal_acc=0.8072
#   SLIDE-level: BA=0.9000 | EMA smoothed=0.9272
#   Best model: epoch 19, BA=1.0000, loss=0.1282
#   Best EMA smoothed: 0.9755 (epoch 14)
#   Patience: 6/20 (remaining: 14)
#   LR: 0.000282
# Iter 29, Fold 4, Epoch 21/100 | train_loss: 0.2821 | train_acc: 0.8688
#   PATCH-level: val_loss=0.2439, bal_acc=0.9190
#   SLIDE-level: BA=1.0000 | EMA smoothed=0.9490
#   Best model: epoch 19, BA=1.0000, loss=0.1282
#   Best EMA smoothed: 0.9755 (epoch 14)
#   Patience: 7/20 (remaining: 13)
#   LR: 0.000280
# Iter 29, Fold 4, Epoch 22/100 | train_loss: 0.1701 | train_acc: 0.8165
#   PATCH-level: val_loss=0.1474, bal_acc=0.9530
#   SLIDE-level: BA=1.0000 | EMA smoothed=0.9643
#   Best model: epoch 19, BA=1.0000, loss=0.1282
#   Best EMA smoothed: 0.9755 (epoch 14)
#   Patience: 8/20 (remaining: 12)
#   LR: 0.000277
# Iter 29, Fold 4, Epoch 23/100 | train_loss: 0.2149 | train_acc: 0.8548
#   PATCH-level: val_loss=0.2019, bal_acc=0.9304
#   SLIDE-level: BA=1.0000 | EMA smoothed=0.9750
#   Best model: epoch 19, BA=1.0000, loss=0.1282
#   Best EMA smoothed: 0.9755 (epoch 14)
#   Patience: 9/20 (remaining: 11)
#   LR: 0.000274
# Iter 29, Fold 4, Epoch 24/100 | train_loss: 0.2198 | train_acc: 0.8182
#   PATCH-level: val_loss=0.5153, bal_acc=0.8580
#   SLIDE-level: BA=1.0000 | EMA smoothed=0.9825
#   Best model: epoch 19, BA=1.0000, loss=0.1282
#   Best EMA smoothed: 0.9755 (epoch 14)
#   Patience: 10/20 (remaining: 10)
#   LR: 0.000271
# Iter 29, Fold 4, Epoch 25/100 | train_loss: 0.1855 | train_acc: 0.8697
#   PATCH-level: val_loss=0.1440, bal_acc=0.9471
#   SLIDE-level: BA=1.0000 | EMA smoothed=0.9878
#   Best model: epoch 19, BA=1.0000, loss=0.1282
#   Best EMA smoothed: 0.9878 (epoch 25)
#   Patience: 0/20 (remaining: 20)
#   LR: 0.000268
# Checkpoint saved: cv_iter_28_fold_3_checkpoint.pth (best_epoch=18)[hash=2cbb5e7002e51df8]
#
#  BEST MODEL at epoch 26 (reason: tied_slide_ba_better_loss)
#    slide_BA: 1.0000 | val_loss: 0.0813
# Iter 29, Fold 4, Epoch 26/100 | train_loss: 0.1314 | train_acc: 0.8561
#   PATCH-level: val_loss=0.0813, bal_acc=0.9797
#   SLIDE-level: BA=1.0000 | EMA smoothed=0.9914
#   Best model: epoch 26, BA=1.0000, loss=0.0813
#   Best EMA smoothed: 0.9878 (epoch 25)
#   Patience: 1/20 (remaining: 19)
#   LR: 0.000265
# Iter 29, Fold 4, Epoch 27/100 | train_loss: 0.1904 | train_acc: 0.8278
#   PATCH-level: val_loss=0.5773, bal_acc=0.8449
#   SLIDE-level: BA=1.0000 | EMA smoothed=0.9940
#   Best model: epoch 26, BA=1.0000, loss=0.0813
#   Best EMA smoothed: 0.9878 (epoch 25)
#   Patience: 2/20 (remaining: 18)
#   LR: 0.000262
# Iter 29, Fold 4, Epoch 28/100 | train_loss: 0.2323 | train_acc: 0.8845
#   PATCH-level: val_loss=0.1251, bal_acc=0.9660
#   SLIDE-level: BA=1.0000 | EMA smoothed=0.9958
#   Best model: epoch 26, BA=1.0000, loss=0.0813
#   Best EMA smoothed: 0.9878 (epoch 25)
#   Patience: 3/20 (remaining: 17)
#   LR: 0.000259
# Iter 29, Fold 4, Epoch 29/100 | train_loss: 0.1513 | train_acc: 0.8910
#   PATCH-level: val_loss=0.1742, bal_acc=0.9452
#   SLIDE-level: BA=1.0000 | EMA smoothed=0.9971
#   Best model: epoch 26, BA=1.0000, loss=0.0813
#   Best EMA smoothed: 0.9878 (epoch 25)
#   Patience: 4/20 (remaining: 16)
#   LR: 0.000255
# Iter 29, Fold 4, Epoch 30/100 | train_loss: 0.1535 | train_acc: 0.8701
#   PATCH-level: val_loss=0.2139, bal_acc=0.9254
#   SLIDE-level: BA=1.0000 | EMA smoothed=0.9979
#   Best model: epoch 26, BA=1.0000, loss=0.0813
#   Best EMA smoothed: 0.9979 (epoch 30)
#   Patience: 0/20 (remaining: 20)
#   LR: 0.000252
# Iter 29, Fold 4, Epoch 31/100 | train_loss: 0.1451 | train_acc: 0.8583
#   PATCH-level: val_loss=0.1707, bal_acc=0.9471
#   SLIDE-level: BA=1.0000 | EMA smoothed=0.9986
#   Best model: epoch 26, BA=1.0000, loss=0.0813
#   Best EMA smoothed: 0.9979 (epoch 30)
#   Patience: 1/20 (remaining: 19)
#   LR: 0.000248
# Iter 29, Fold 4, Epoch 32/100 | train_loss: 0.1958 | train_acc: 0.8518
#   PATCH-level: val_loss=0.1103, bal_acc=0.9664
#   SLIDE-level: BA=1.0000 | EMA smoothed=0.9990
#   Best model: epoch 26, BA=1.0000, loss=0.0813
#   Best EMA smoothed: 0.9979 (epoch 30)
#   Patience: 2/20 (remaining: 18)
#   LR: 0.000244
# Iter 29, Fold 4, Epoch 33/100 | train_loss: 0.1092 | train_acc: 0.8884
#   PATCH-level: val_loss=0.1748, bal_acc=0.9513
#   SLIDE-level: BA=1.0000 | EMA smoothed=0.9993
#   Best model: epoch 26, BA=1.0000, loss=0.0813
#   Best EMA smoothed: 0.9979 (epoch 30)
#   Patience: 3/20 (remaining: 17)
#   LR: 0.000240
# Iter 29, Fold 4, Epoch 34/100 | train_loss: 0.1901 | train_acc: 0.8287
#   PATCH-level: val_loss=0.1401, bal_acc=0.9536
#   SLIDE-level: BA=1.0000 | EMA smoothed=0.9995
#   Best model: epoch 26, BA=1.0000, loss=0.0813
#   Best EMA smoothed: 0.9979 (epoch 30)
#   Patience: 4/20 (remaining: 16)
#   LR: 0.000236
# Iter 29, Fold 4, Epoch 35/100 | train_loss: 0.1967 | train_acc: 0.8500
#   PATCH-level: val_loss=1.0629, bal_acc=0.7627
#   SLIDE-level: BA=0.8000 | EMA smoothed=0.9397
#   Best model: epoch 26, BA=1.0000, loss=0.0813
#   Best EMA smoothed: 0.9979 (epoch 30)
#   Patience: 5/20 (remaining: 15)
#   LR: 0.000232
# Iter 29, Fold 4, Epoch 36/100 | train_loss: 0.1336 | train_acc: 0.8727
#   PATCH-level: val_loss=0.1295, bal_acc=0.9627
#   SLIDE-level: BA=1.0000 | EMA smoothed=0.9578
#   Best model: epoch 26, BA=1.0000, loss=0.0813
#   Best EMA smoothed: 0.9979 (epoch 30)
#   Patience: 6/20 (remaining: 14)
#   LR: 0.000228
# Iter 29, Fold 4, Epoch 37/100 | train_loss: 0.1800 | train_acc: 0.8723
#   PATCH-level: val_loss=0.4068, bal_acc=0.9003
#   SLIDE-level: BA=1.0000 | EMA smoothed=0.9704
#   Best model: epoch 26, BA=1.0000, loss=0.0813
#   Best EMA smoothed: 0.9979 (epoch 30)
#   Patience: 7/20 (remaining: 13)
#   LR: 0.000224
# Iter 29, Fold 4, Epoch 38/100 | train_loss: 0.2071 | train_acc: 0.8413
#   PATCH-level: val_loss=0.2287, bal_acc=0.9187
#   SLIDE-level: BA=1.0000 | EMA smoothed=0.9793
#   Best model: epoch 26, BA=1.0000, loss=0.0813
#   Best EMA smoothed: 0.9979 (epoch 30)
#   Patience: 8/20 (remaining: 12)
#   LR: 0.000219
# Iter 29, Fold 4, Epoch 39/100 | train_loss: 0.1670 | train_acc: 0.8954
#   PATCH-level: val_loss=0.6573, bal_acc=0.8064
#   SLIDE-level: BA=0.8000 | EMA smoothed=0.9255
#   Best model: epoch 26, BA=1.0000, loss=0.0813
#   Best EMA smoothed: 0.9979 (epoch 30)
#   Patience: 9/20 (remaining: 11)
#   LR: 0.000215
# Iter 29, Fold 4, Epoch 40/100 | train_loss: 0.1442 | train_acc: 0.9063
#   PATCH-level: val_loss=0.1370, bal_acc=0.9560
#   SLIDE-level: BA=1.0000 | EMA smoothed=0.9479
#   Best model: epoch 26, BA=1.0000, loss=0.0813
#   Best EMA smoothed: 0.9979 (epoch 30)
#   Patience: 10/20 (remaining: 10)
#   LR: 0.000211
# Iter 29, Fold 4, Epoch 41/100 | train_loss: 0.1536 | train_acc: 0.8330
#   PATCH-level: val_loss=0.5133, bal_acc=0.8621
#   SLIDE-level: BA=1.0000 | EMA smoothed=0.9635
#   Best model: epoch 26, BA=1.0000, loss=0.0813
#   Best EMA smoothed: 0.9979 (epoch 30)
#   Patience: 11/20 (remaining: 9)
#   LR: 0.000206
# Iter 29, Fold 4, Epoch 42/100 | train_loss: 0.1338 | train_acc: 0.9071
#   PATCH-level: val_loss=0.5039, bal_acc=0.8627
#   SLIDE-level: BA=1.0000 | EMA smoothed=0.9745
#   Best model: epoch 26, BA=1.0000, loss=0.0813
#   Best EMA smoothed: 0.9979 (epoch 30)
#   Patience: 12/20 (remaining: 8)
#   LR: 0.000201
# Iter 29, Fold 4, Epoch 43/100 | train_loss: 0.1253 | train_acc: 0.9058
#   PATCH-level: val_loss=0.2319, bal_acc=0.9284
#   SLIDE-level: BA=1.0000 | EMA smoothed=0.9821
#   Best model: epoch 26, BA=1.0000, loss=0.0813
#   Best EMA smoothed: 0.9979 (epoch 30)
#   Patience: 13/20 (remaining: 7)
#   LR: 0.000197
# Iter 29, Fold 4, Epoch 44/100 | train_loss: 0.1037 | train_acc: 0.8766
#   PATCH-level: val_loss=0.5635, bal_acc=0.8393
#   SLIDE-level: BA=1.0000 | EMA smoothed=0.9875
#   Best model: epoch 26, BA=1.0000, loss=0.0813
#   Best EMA smoothed: 0.9979 (epoch 30)
#   Patience: 14/20 (remaining: 6)
#   LR: 0.000192
# Iter 29, Fold 4, Epoch 45/100 | train_loss: 0.1130 | train_acc: 0.8710
#   PATCH-level: val_loss=0.7117, bal_acc=0.8259
#   SLIDE-level: BA=0.8000 | EMA smoothed=0.9312
#   Best model: epoch 26, BA=1.0000, loss=0.0813
#   Best EMA smoothed: 0.9979 (epoch 30)
#   Patience: 15/20 (remaining: 5)
#   LR: 0.000187
# Iter 29, Fold 4, Epoch 46/100 | train_loss: 0.1386 | train_acc: 0.8492
#   PATCH-level: val_loss=0.2995, bal_acc=0.8942
#   SLIDE-level: BA=1.0000 | EMA smoothed=0.9519
#   Best model: epoch 26, BA=1.0000, loss=0.0813
#   Best EMA smoothed: 0.9979 (epoch 30)
#   Patience: 16/20 (remaining: 4)
#   LR: 0.000182
# Iter 29, Fold 4, Epoch 47/100 | train_loss: 0.1783 | train_acc: 0.8400
#   PATCH-level: val_loss=0.2595, bal_acc=0.8911
#   SLIDE-level: BA=1.0000 | EMA smoothed=0.9663
#   Best model: epoch 26, BA=1.0000, loss=0.0813
#   Best EMA smoothed: 0.9979 (epoch 30)
#   Patience: 17/20 (remaining: 3)
#   LR: 0.000178
# Iter 29, Fold 4, Epoch 48/100 | train_loss: 0.1105 | train_acc: 0.9259
#   PATCH-level: val_loss=0.3107, bal_acc=0.9070
#   SLIDE-level: BA=1.0000 | EMA smoothed=0.9764
#   Best model: epoch 26, BA=1.0000, loss=0.0813
#   Best EMA smoothed: 0.9979 (epoch 30)
#   Patience: 18/20 (remaining: 2)
#   LR: 0.000173
# Iter 29, Fold 4, Epoch 49/100 | train_loss: 0.1424 | train_acc: 0.8784
#   PATCH-level: val_loss=0.1173, bal_acc=0.9624
#   SLIDE-level: BA=1.0000 | EMA smoothed=0.9835
#   Best model: epoch 26, BA=1.0000, loss=0.0813
#   Best EMA smoothed: 0.9979 (epoch 30)
#   Patience: 19/20 (remaining: 1)
#   LR: 0.000168
# Iter 29, Fold 4, Epoch 50/100 | train_loss: 0.1663 | train_acc: 0.8762
#   PATCH-level: val_loss=0.1958, bal_acc=0.9251
#   SLIDE-level: BA=1.0000 | EMA smoothed=0.9884
#   Best model: epoch 26, BA=1.0000, loss=0.0813
#   Best EMA smoothed: 0.9979 (epoch 30)
#   Patience: 20/20 (remaining: 0)
#   LR: 0.000163
# Checkpoint saved: cv_iter_28_fold_3_checkpoint.pth (best_epoch=25)[hash=2cbb5e7002e51df8]
#
#  EARLY STOPPING triggered at epoch 50
#    Best model: epoch 26
#    slide_BA=1.0000,    val_loss=0.0813
#    Best EMA smoothed: 0.9979 (epoch 30)
#
# RESTORED best model weights from epoch 26
#       1. slide_BA (maximize): 1.0000
#       2. val_loss (minimize): 0.0813
#     EMA smoothed at that epoch: 0.9914
#
# Saving FINAL checkpoint and history for Iter 29 Fold 4...
# Checkpoint saved: cv_iter_28_fold_3_checkpoint.pth (best_epoch=25)[hash=2cbb5e7002e51df8]
#
# Iter 29 Fold 4 Summary (at best epoch 26):
#   SLIDE-LEVEL:
#     Balanced Acc: 1.0000
#     Val Loss:     0.0813
#     EMA smoothed: 0.9914
#     MCC: 1.0000
#     AUC: 1.0000
#   PATCH-LEVEL:
#     Balanced Acc: 0.9797
#     MCC: 0.9569
#   Training time: 1219.27s
#   Cleaned local checkpoint: iter_28_fold_2
#   Cleaned Drive checkpoint: iter_28_fold_2
# Fold 5/5
#
# Calculating normalization statistics from training set...
#   Mean: ['0.2368']
#   Std:  ['0.0075']
# Using uniform class weights (gamma=0, recommended with MixUp)
#
# Training fold 5...
#
# ======================================================================
# ITERATION 29/30 | FOLD 5/5
# Iteration Seed: 168388230
# Validation: ~9 slides, 528 patches
# Starting fold from scratch
# Model initialization seed: 3636547837
#   Model config:
#     init_policy          : default
#     dim_head             : 64
#     pe_temperature       : 10000
#     convtok_hidden_ch    : 64
#     arch_hash            : 2cbb5e7002e51df8
# [ConvTok] Analytical output grid: (24, 24) (N=576) for 384×384 input
# [ConvTok] Analytical matched-N assertion passed at construction: (24, 24) = (24, 24), N=576
#   Model created (seed=3636547837): 5,409,346 params (5,409,346 trainable)
#   [ConvTok diag] Token stats (post-ConvTok+LN, dummy batch): mean=-0.0000, std=1.0000, grid=(24,24), N=576
# [ConvTok] Runtime token grid (forward #1): H'=24, W'=24, N=576
# [ConvTok] Matched-N assertion passed (forward #1): (24, 24) = (24, 24), N=576
#
#  BEST MODEL at epoch 1 (reason: first_epoch)
#    slide_BA: 0.6500 | val_loss: 0.6887
# Iter 29, Fold 5, Epoch 1/100 | train_loss: 0.6339 | train_acc: 0.6524
#   PATCH-level: val_loss=0.6887, bal_acc=0.5777
#   SLIDE-level: BA=0.6500 | EMA smoothed=0.6500
#   Best model: epoch 1, BA=0.6500, loss=0.6887
#   Best EMA smoothed: 0.6500 (epoch 1)
#   Patience: 1/20 (remaining: 19)
#   LR: 0.000120
#
#  BEST MODEL at epoch 2 (reason: better_slide_ba)
#    slide_BA: 0.8750 | val_loss: 0.5921
# Iter 29, Fold 5, Epoch 2/100 | train_loss: 0.6042 | train_acc: 0.6373
#   PATCH-level: val_loss=0.5921, bal_acc=0.6991
#   SLIDE-level: BA=0.8750 | EMA smoothed=0.7175
#   Best model: epoch 2, BA=0.8750, loss=0.5921
#   Best EMA smoothed: 0.7175 (epoch 2)
#   Patience: 0/20 (remaining: 20)
#   LR: 0.000180
# Iter 29, Fold 5, Epoch 3/100 | train_loss: 0.5401 | train_acc: 0.6725
#   PATCH-level: val_loss=0.6304, bal_acc=0.7283
#   SLIDE-level: BA=0.8000 | EMA smoothed=0.7422
#   Best model: epoch 2, BA=0.8750, loss=0.5921
#   Best EMA smoothed: 0.7422 (epoch 3)
#   Patience: 0/20 (remaining: 20)
#   LR: 0.000240
#
#  BEST MODEL at epoch 4 (reason: tied_slide_ba_better_loss)
#    slide_BA: 0.8750 | val_loss: 0.2908
# Iter 29, Fold 5, Epoch 4/100 | train_loss: 0.4459 | train_acc: 0.8065
#   PATCH-level: val_loss=0.2908, bal_acc=0.8793
#   SLIDE-level: BA=0.8750 | EMA smoothed=0.7821
#   Best model: epoch 4, BA=0.8750, loss=0.2908
#   Best EMA smoothed: 0.7821 (epoch 4)
#   Patience: 0/20 (remaining: 20)
#   LR: 0.000300
# Iter 29, Fold 5, Epoch 5/100 | train_loss: 0.3364 | train_acc: 0.8128
#   PATCH-level: val_loss=0.4157, bal_acc=0.8162
#   SLIDE-level: BA=0.8000 | EMA smoothed=0.7875
#   Best model: epoch 4, BA=0.8750, loss=0.2908
#   Best EMA smoothed: 0.7821 (epoch 4)
#   Patience: 1/20 (remaining: 19)
#   LR: 0.000300
#
#  BEST MODEL at epoch 6 (reason: better_slide_ba)
#    slide_BA: 1.0000 | val_loss: 0.2297
# Iter 29, Fold 5, Epoch 6/100 | train_loss: 0.4458 | train_acc: 0.7225
#   PATCH-level: val_loss=0.2297, bal_acc=0.9071
#   SLIDE-level: BA=1.0000 | EMA smoothed=0.8512
#   Best model: epoch 6, BA=1.0000, loss=0.2297
#   Best EMA smoothed: 0.8512 (epoch 6)
#   Patience: 0/20 (remaining: 20)
#   LR: 0.000300
# Iter 29, Fold 5, Epoch 7/100 | train_loss: 0.2375 | train_acc: 0.8052
#   PATCH-level: val_loss=0.9840, bal_acc=0.6464
#   SLIDE-level: BA=0.6250 | EMA smoothed=0.7834
#   Best model: epoch 6, BA=1.0000, loss=0.2297
#   Best EMA smoothed: 0.8512 (epoch 6)
#   Patience: 1/20 (remaining: 19)
#   LR: 0.000300
#
#  BEST MODEL at epoch 8 (reason: tied_slide_ba_better_loss)
#    slide_BA: 1.0000 | val_loss: 0.2160
# Iter 29, Fold 5, Epoch 8/100 | train_loss: 0.4717 | train_acc: 0.7859
#   PATCH-level: val_loss=0.2160, bal_acc=0.9158
#   SLIDE-level: BA=1.0000 | EMA smoothed=0.8483
#   Best model: epoch 8, BA=1.0000, loss=0.2160
#   Best EMA smoothed: 0.8512 (epoch 6)
#   Patience: 2/20 (remaining: 18)
#   LR: 0.000299
#
#  BEST MODEL at epoch 9 (reason: tied_slide_ba_better_loss)
#    slide_BA: 1.0000 | val_loss: 0.1894
# Iter 29, Fold 5, Epoch 9/100 | train_loss: 0.3314 | train_acc: 0.8111
#   PATCH-level: val_loss=0.1894, bal_acc=0.9293
#   SLIDE-level: BA=1.0000 | EMA smoothed=0.8938
#   Best model: epoch 9, BA=1.0000, loss=0.1894
#   Best EMA smoothed: 0.8938 (epoch 9)
#   Patience: 0/20 (remaining: 20)
#   LR: 0.000299
# Iter 29, Fold 5, Epoch 10/100 | train_loss: 0.2564 | train_acc: 0.8018
#   PATCH-level: val_loss=0.4758, bal_acc=0.8149
#   SLIDE-level: BA=0.7500 | EMA smoothed=0.8507
#   Best model: epoch 9, BA=1.0000, loss=0.1894
#   Best EMA smoothed: 0.8938 (epoch 9)
#   Patience: 1/20 (remaining: 19)
#   LR: 0.000298
# Iter 29, Fold 5, Epoch 11/100 | train_loss: 0.3000 | train_acc: 0.7859
#   PATCH-level: val_loss=0.1911, bal_acc=0.9136
#   SLIDE-level: BA=0.8750 | EMA smoothed=0.8580
#   Best model: epoch 9, BA=1.0000, loss=0.1894
#   Best EMA smoothed: 0.8938 (epoch 9)
#   Patience: 2/20 (remaining: 18)
#   LR: 0.000297
#
#  BEST MODEL at epoch 12 (reason: tied_slide_ba_better_loss)
#    slide_BA: 1.0000 | val_loss: 0.1458
# Iter 29, Fold 5, Epoch 12/100 | train_loss: 0.3028 | train_acc: 0.8123
#   PATCH-level: val_loss=0.1458, bal_acc=0.9425
#   SLIDE-level: BA=1.0000 | EMA smoothed=0.9006
#   Best model: epoch 12, BA=1.0000, loss=0.1458
#   Best EMA smoothed: 0.8938 (epoch 9)
#   Patience: 3/20 (remaining: 17)
#   LR: 0.000296
# Iter 29, Fold 5, Epoch 13/100 | train_loss: 0.2237 | train_acc: 0.7809
#   PATCH-level: val_loss=0.2845, bal_acc=0.8792
#   SLIDE-level: BA=0.8750 | EMA smoothed=0.8929
#   Best model: epoch 12, BA=1.0000, loss=0.1458
#   Best EMA smoothed: 0.8938 (epoch 9)
#   Patience: 4/20 (remaining: 16)
#   LR: 0.000295
#
#  BEST MODEL at epoch 14 (reason: tied_slide_ba_better_loss)
#    slide_BA: 1.0000 | val_loss: 0.1258
# Iter 29, Fold 5, Epoch 14/100 | train_loss: 0.2398 | train_acc: 0.8476
#   PATCH-level: val_loss=0.1258, bal_acc=0.9542
#   SLIDE-level: BA=1.0000 | EMA smoothed=0.9250
#   Best model: epoch 14, BA=1.0000, loss=0.1258
#   Best EMA smoothed: 0.9250 (epoch 14)
#   Patience: 0/20 (remaining: 20)
#   LR: 0.000293
# Iter 29, Fold 5, Epoch 15/100 | train_loss: 0.2716 | train_acc: 0.8203
#   PATCH-level: val_loss=0.1571, bal_acc=0.9281
#   SLIDE-level: BA=1.0000 | EMA smoothed=0.9475
#   Best model: epoch 14, BA=1.0000, loss=0.1258
#   Best EMA smoothed: 0.9475 (epoch 15)
#   Patience: 0/20 (remaining: 20)
#   LR: 0.000292
# Iter 29, Fold 5, Epoch 16/100 | train_loss: 0.2779 | train_acc: 0.7859
#   PATCH-level: val_loss=0.1554, bal_acc=0.9497
#   SLIDE-level: BA=1.0000 | EMA smoothed=0.9633
#   Best model: epoch 14, BA=1.0000, loss=0.1258
#   Best EMA smoothed: 0.9633 (epoch 16)
#   Patience: 0/20 (remaining: 20)
#   LR: 0.000290
# Iter 29, Fold 5, Epoch 17/100 | train_loss: 0.2586 | train_acc: 0.8006
#   PATCH-level: val_loss=0.1550, bal_acc=0.9442
#   SLIDE-level: BA=1.0000 | EMA smoothed=0.9743
#   Best model: epoch 14, BA=1.0000, loss=0.1258
#   Best EMA smoothed: 0.9743 (epoch 17)
#   Patience: 0/20 (remaining: 20)
#   LR: 0.000288
# Iter 29, Fold 5, Epoch 18/100 | train_loss: 0.1995 | train_acc: 0.8463
#   PATCH-level: val_loss=0.1860, bal_acc=0.9287
#   SLIDE-level: BA=1.0000 | EMA smoothed=0.9820
#   Best model: epoch 14, BA=1.0000, loss=0.1258
#   Best EMA smoothed: 0.9743 (epoch 17)
#   Patience: 1/20 (remaining: 19)
#   LR: 0.000286
# Iter 29, Fold 5, Epoch 19/100 | train_loss: 0.1869 | train_acc: 0.8484
#   PATCH-level: val_loss=0.2180, bal_acc=0.9079
#   SLIDE-level: BA=0.8750 | EMA smoothed=0.9499
#   Best model: epoch 14, BA=1.0000, loss=0.1258
#   Best EMA smoothed: 0.9743 (epoch 17)
#   Patience: 2/20 (remaining: 18)
#   LR: 0.000284
# Iter 29, Fold 5, Epoch 20/100 | train_loss: 0.1613 | train_acc: 0.8237
#   PATCH-level: val_loss=0.2250, bal_acc=0.9258
#   SLIDE-level: BA=1.0000 | EMA smoothed=0.9649
#   Best model: epoch 14, BA=1.0000, loss=0.1258
#   Best EMA smoothed: 0.9743 (epoch 17)
#   Patience: 3/20 (remaining: 17)
#   LR: 0.000282
# Iter 29, Fold 5, Epoch 21/100 | train_loss: 0.1296 | train_acc: 0.8606
#   PATCH-level: val_loss=0.1700, bal_acc=0.9558
#   SLIDE-level: BA=1.0000 | EMA smoothed=0.9755
#   Best model: epoch 14, BA=1.0000, loss=0.1258
#   Best EMA smoothed: 0.9743 (epoch 17)
#   Patience: 4/20 (remaining: 16)
#   LR: 0.000280
# Iter 29, Fold 5, Epoch 22/100 | train_loss: 0.1533 | train_acc: 0.8976
#   PATCH-level: val_loss=0.1453, bal_acc=0.9480
#   SLIDE-level: BA=1.0000 | EMA smoothed=0.9828
#   Best model: epoch 14, BA=1.0000, loss=0.1258
#   Best EMA smoothed: 0.9743 (epoch 17)
#   Patience: 5/20 (remaining: 15)
#   LR: 0.000277
# Iter 29, Fold 5, Epoch 23/100 | train_loss: 0.1539 | train_acc: 0.8665
#   PATCH-level: val_loss=0.4296, bal_acc=0.8936
#   SLIDE-level: BA=1.0000 | EMA smoothed=0.9880
#   Best model: epoch 14, BA=1.0000, loss=0.1258
#   Best EMA smoothed: 0.9880 (epoch 23)
#   Patience: 0/20 (remaining: 20)
#   LR: 0.000274
#
#  BEST MODEL at epoch 24 (reason: tied_slide_ba_better_loss)
#    slide_BA: 1.0000 | val_loss: 0.1132
# Iter 29, Fold 5, Epoch 24/100 | train_loss: 0.2175 | train_acc: 0.8270
#   PATCH-level: val_loss=0.1132, bal_acc=0.9587
#   SLIDE-level: BA=1.0000 | EMA smoothed=0.9916
#   Best model: epoch 24, BA=1.0000, loss=0.1132
#   Best EMA smoothed: 0.9880 (epoch 23)
#   Patience: 1/20 (remaining: 19)
#   LR: 0.000271
# Iter 29, Fold 5, Epoch 25/100 | train_loss: 0.1450 | train_acc: 0.9202
#   PATCH-level: val_loss=0.1315, bal_acc=0.9616
#   SLIDE-level: BA=1.0000 | EMA smoothed=0.9941
#   Best model: epoch 24, BA=1.0000, loss=0.1132
#   Best EMA smoothed: 0.9880 (epoch 23)
#   Patience: 2/20 (remaining: 18)
#   LR: 0.000268
# Checkpoint saved: cv_iter_28_fold_4_checkpoint.pth (best_epoch=23)[hash=2cbb5e7002e51df8]
# Iter 29, Fold 5, Epoch 26/100 | train_loss: 0.2017 | train_acc: 0.8119
#   PATCH-level: val_loss=0.1259, bal_acc=0.9503
#   SLIDE-level: BA=1.0000 | EMA smoothed=0.9959
#   Best model: epoch 24, BA=1.0000, loss=0.1132
#   Best EMA smoothed: 0.9880 (epoch 23)
#   Patience: 3/20 (remaining: 17)
#   LR: 0.000265
#
#  BEST MODEL at epoch 27 (reason: tied_slide_ba_better_loss)
#    slide_BA: 1.0000 | val_loss: 0.1122
# Iter 29, Fold 5, Epoch 27/100 | train_loss: 0.1590 | train_acc: 0.8577
#   PATCH-level: val_loss=0.1122, bal_acc=0.9611
#   SLIDE-level: BA=1.0000 | EMA smoothed=0.9971
#   Best model: epoch 27, BA=1.0000, loss=0.1122
#   Best EMA smoothed: 0.9880 (epoch 23)
#   Patience: 4/20 (remaining: 16)
#   LR: 0.000262
# Iter 29, Fold 5, Epoch 28/100 | train_loss: 0.1402 | train_acc: 0.8862
#   PATCH-level: val_loss=0.2007, bal_acc=0.9169
#   SLIDE-level: BA=0.8750 | EMA smoothed=0.9605
#   Best model: epoch 27, BA=1.0000, loss=0.1122
#   Best EMA smoothed: 0.9880 (epoch 23)
#   Patience: 5/20 (remaining: 15)
#   LR: 0.000259
# Iter 29, Fold 5, Epoch 29/100 | train_loss: 0.1143 | train_acc: 0.8308
#   PATCH-level: val_loss=0.1973, bal_acc=0.9396
#   SLIDE-level: BA=1.0000 | EMA smoothed=0.9723
#   Best model: epoch 27, BA=1.0000, loss=0.1122
#   Best EMA smoothed: 0.9880 (epoch 23)
#   Patience: 6/20 (remaining: 14)
#   LR: 0.000255
# Iter 29, Fold 5, Epoch 30/100 | train_loss: 0.1367 | train_acc: 0.8862
#   PATCH-level: val_loss=0.1988, bal_acc=0.9327
#   SLIDE-level: BA=0.8750 | EMA smoothed=0.9431
#   Best model: epoch 27, BA=1.0000, loss=0.1122
#   Best EMA smoothed: 0.9880 (epoch 23)
#   Patience: 7/20 (remaining: 13)
#   LR: 0.000252
# Iter 29, Fold 5, Epoch 31/100 | train_loss: 0.1301 | train_acc: 0.8976
#   PATCH-level: val_loss=0.1856, bal_acc=0.9259
#   SLIDE-level: BA=0.8750 | EMA smoothed=0.9227
#   Best model: epoch 27, BA=1.0000, loss=0.1122
#   Best EMA smoothed: 0.9880 (epoch 23)
#   Patience: 8/20 (remaining: 12)
#   LR: 0.000248
# Iter 29, Fold 5, Epoch 32/100 | train_loss: 0.0955 | train_acc: 0.9055
#   PATCH-level: val_loss=0.1281, bal_acc=0.9564
#   SLIDE-level: BA=1.0000 | EMA smoothed=0.9459
#   Best model: epoch 27, BA=1.0000, loss=0.1122
#   Best EMA smoothed: 0.9880 (epoch 23)
#   Patience: 9/20 (remaining: 11)
#   LR: 0.000244
# Iter 29, Fold 5, Epoch 33/100 | train_loss: 0.2022 | train_acc: 0.8728
#   PATCH-level: val_loss=0.1402, bal_acc=0.9628
#   SLIDE-level: BA=1.0000 | EMA smoothed=0.9621
#   Best model: epoch 27, BA=1.0000, loss=0.1122
#   Best EMA smoothed: 0.9880 (epoch 23)
#   Patience: 10/20 (remaining: 10)
#   LR: 0.000240
# Iter 29, Fold 5, Epoch 34/100 | train_loss: 0.1065 | train_acc: 0.9165
#   PATCH-level: val_loss=0.1829, bal_acc=0.9394
#   SLIDE-level: BA=0.8750 | EMA smoothed=0.9360
#   Best model: epoch 27, BA=1.0000, loss=0.1122
#   Best EMA smoothed: 0.9880 (epoch 23)
#   Patience: 11/20 (remaining: 9)
#   LR: 0.000236
# Iter 29, Fold 5, Epoch 35/100 | train_loss: 0.1388 | train_acc: 0.8724
#   PATCH-level: val_loss=0.1206, bal_acc=0.9753
#   SLIDE-level: BA=1.0000 | EMA smoothed=0.9552
#   Best model: epoch 27, BA=1.0000, loss=0.1122
#   Best EMA smoothed: 0.9880 (epoch 23)
#   Patience: 12/20 (remaining: 8)
#   LR: 0.000232
#
#  BEST MODEL at epoch 36 (reason: tied_slide_ba_better_loss)
#    slide_BA: 1.0000 | val_loss: 0.1105
# Iter 29, Fold 5, Epoch 36/100 | train_loss: 0.1154 | train_acc: 0.9106
#   PATCH-level: val_loss=0.1105, bal_acc=0.9677
#   SLIDE-level: BA=1.0000 | EMA smoothed=0.9686
#   Best model: epoch 36, BA=1.0000, loss=0.1105
#   Best EMA smoothed: 0.9880 (epoch 23)
#   Patience: 13/20 (remaining: 7)
#   LR: 0.000228
# Iter 29, Fold 5, Epoch 37/100 | train_loss: 0.1604 | train_acc: 0.8300
#   PATCH-level: val_loss=0.1201, bal_acc=0.9564
#   SLIDE-level: BA=1.0000 | EMA smoothed=0.9780
#   Best model: epoch 36, BA=1.0000, loss=0.1105
#   Best EMA smoothed: 0.9880 (epoch 23)
#   Patience: 14/20 (remaining: 6)
#   LR: 0.000224
#
#  BEST MODEL at epoch 38 (reason: tied_slide_ba_better_loss)
#    slide_BA: 1.0000 | val_loss: 0.1097
# Iter 29, Fold 5, Epoch 38/100 | train_loss: 0.1600 | train_acc: 0.8917
#   PATCH-level: val_loss=0.1097, bal_acc=0.9535
#   SLIDE-level: BA=1.0000 | EMA smoothed=0.9846
#   Best model: epoch 38, BA=1.0000, loss=0.1097
#   Best EMA smoothed: 0.9880 (epoch 23)
#   Patience: 15/20 (remaining: 5)
#   LR: 0.000219
# Iter 29, Fold 5, Epoch 39/100 | train_loss: 0.1274 | train_acc: 0.8140
#   PATCH-level: val_loss=0.1319, bal_acc=0.9580
#   SLIDE-level: BA=1.0000 | EMA smoothed=0.9892
#   Best model: epoch 38, BA=1.0000, loss=0.1097
#   Best EMA smoothed: 0.9880 (epoch 23)
#   Patience: 16/20 (remaining: 4)
#   LR: 0.000215
#
#  BEST MODEL at epoch 40 (reason: tied_slide_ba_better_loss)
#    slide_BA: 1.0000 | val_loss: 0.1034
# Iter 29, Fold 5, Epoch 40/100 | train_loss: 0.1565 | train_acc: 0.8732
#   PATCH-level: val_loss=0.1034, bal_acc=0.9699
#   SLIDE-level: BA=1.0000 | EMA smoothed=0.9925
#   Best model: epoch 40, BA=1.0000, loss=0.1034
#   Best EMA smoothed: 0.9880 (epoch 23)
#   Patience: 17/20 (remaining: 3)
#   LR: 0.000211
#
#  BEST MODEL at epoch 41 (reason: tied_slide_ba_better_loss)
#    slide_BA: 1.0000 | val_loss: 0.0866
# Iter 29, Fold 5, Epoch 41/100 | train_loss: 0.1530 | train_acc: 0.9186
#   PATCH-level: val_loss=0.0866, bal_acc=0.9716
#   SLIDE-level: BA=1.0000 | EMA smoothed=0.9947
#   Best model: epoch 41, BA=1.0000, loss=0.0866
#   Best EMA smoothed: 0.9880 (epoch 23)
#   Patience: 18/20 (remaining: 2)
#   LR: 0.000206
# Iter 29, Fold 5, Epoch 42/100 | train_loss: 0.1485 | train_acc: 0.9068
#   PATCH-level: val_loss=0.1379, bal_acc=0.9665
#   SLIDE-level: BA=1.0000 | EMA smoothed=0.9963
#   Best model: epoch 41, BA=1.0000, loss=0.0866
#   Best EMA smoothed: 0.9880 (epoch 23)
#   Patience: 19/20 (remaining: 1)
#   LR: 0.000201
# Iter 29, Fold 5, Epoch 43/100 | train_loss: 0.1136 | train_acc: 0.8871
#   PATCH-level: val_loss=0.2378, bal_acc=0.9365
#   SLIDE-level: BA=0.8750 | EMA smoothed=0.9599
#   Best model: epoch 41, BA=1.0000, loss=0.0866
#   Best EMA smoothed: 0.9880 (epoch 23)
#   Patience: 20/20 (remaining: 0)
#   LR: 0.000197
# Checkpoint saved: cv_iter_28_fold_4_checkpoint.pth (best_epoch=40)[hash=2cbb5e7002e51df8]
#
#  EARLY STOPPING triggered at epoch 43
#    Best model: epoch 41
#    slide_BA=1.0000,    val_loss=0.0866
#    Best EMA smoothed: 0.9880 (epoch 23)
#
# RESTORED best model weights from epoch 41
#       1. slide_BA (maximize): 1.0000
#       2. val_loss (minimize): 0.0866
#     EMA smoothed at that epoch: 0.9947
#
# Saving FINAL checkpoint and history for Iter 29 Fold 5...
# Checkpoint saved: cv_iter_28_fold_4_checkpoint.pth (best_epoch=40)[hash=2cbb5e7002e51df8]
#
# Iter 29 Fold 5 Summary (at best epoch 41):
#   SLIDE-LEVEL:
#     Balanced Acc: 1.0000
#     Val Loss:     0.0866
#     EMA smoothed: 0.9947
#     MCC: 1.0000
#     AUC: 1.0000
#   PATCH-LEVEL:
#     Balanced Acc: 0.9716
#     MCC: 0.9456
#   Training time: 1100.02s
#   Cleaned local checkpoint: iter_28_fold_3
#   Cleaned Drive checkpoint: iter_28_fold_3
#
# ======================================================================
# ITERATION 30/30 | base seed 911875363
# ======================================================================
#
# ✓ Valid splits found on first attempt
#   Effective seed: 911875363
# Fold 1/5
#
# Calculating normalization statistics from training set...
#   Mean: ['0.2370']
#   Std:  ['0.0073']
# Using uniform class weights (gamma=0, recommended with MixUp)
#
# Training fold 1...
#
# ======================================================================
# ITERATION 30/30 | FOLD 1/5
# Iteration Seed: 911875363
# Validation: ~10 slides, 681 patches
# Starting fold from scratch
# Model initialization seed: 1279365617
#   Model config:
#     init_policy          : default
#     dim_head             : 64
#     pe_temperature       : 10000
#     convtok_hidden_ch    : 64
#     arch_hash            : 2cbb5e7002e51df8
# [ConvTok] Analytical output grid: (24, 24) (N=576) for 384×384 input
# [ConvTok] Analytical matched-N assertion passed at construction: (24, 24) = (24, 24), N=576
#   Model created (seed=1279365617): 5,409,346 params (5,409,346 trainable)
#   [ConvTok diag] Token stats (post-ConvTok+LN, dummy batch): mean=0.0000, std=1.0000, grid=(24,24), N=576
# [ConvTok] Runtime token grid (forward #1): H'=24, W'=24, N=576
# [ConvTok] Matched-N assertion passed (forward #1): (24, 24) = (24, 24), N=576
#
#  BEST MODEL at epoch 1 (reason: first_epoch)
#    slide_BA: 0.7917 | val_loss: 0.6111
# Iter 30, Fold 1, Epoch 1/100 | train_loss: 0.6560 | train_acc: 0.6021
#   PATCH-level: val_loss=0.6111, bal_acc=0.7262
#   SLIDE-level: BA=0.7917 | EMA smoothed=0.7917
#   Best model: epoch 1, BA=0.7917, loss=0.6111
#   Best EMA smoothed: 0.7917 (epoch 1)
#   Patience: 1/20 (remaining: 19)
#   LR: 0.000120
# Iter 30, Fold 1, Epoch 2/100 | train_loss: 0.6342 | train_acc: 0.6487
#   PATCH-level: val_loss=0.9421, bal_acc=0.6173
#   SLIDE-level: BA=0.6667 | EMA smoothed=0.7542
#   Best model: epoch 1, BA=0.7917, loss=0.6111
#   Best EMA smoothed: 0.7917 (epoch 1)
#   Patience: 2/20 (remaining: 18)
#   LR: 0.000180
# Iter 30, Fold 1, Epoch 3/100 | train_loss: 0.6336 | train_acc: 0.6487
#   PATCH-level: val_loss=1.0076, bal_acc=0.5681
#   SLIDE-level: BA=0.5833 | EMA smoothed=0.7029
#   Best model: epoch 1, BA=0.7917, loss=0.6111
#   Best EMA smoothed: 0.7917 (epoch 1)
#   Patience: 3/20 (remaining: 17)
#   LR: 0.000240
# Iter 30, Fold 1, Epoch 4/100 | train_loss: 0.4751 | train_acc: 0.6976
#   PATCH-level: val_loss=0.9212, bal_acc=0.6531
#   SLIDE-level: BA=0.5833 | EMA smoothed=0.6670
#   Best model: epoch 1, BA=0.7917, loss=0.6111
#   Best EMA smoothed: 0.7917 (epoch 1)
#   Patience: 4/20 (remaining: 16)
#   LR: 0.000300
#
#  BEST MODEL at epoch 5 (reason: better_slide_ba)
#    slide_BA: 0.9167 | val_loss: 0.2704
# Iter 30, Fold 1, Epoch 5/100 | train_loss: 0.3947 | train_acc: 0.7568
#   PATCH-level: val_loss=0.2704, bal_acc=0.9085
#   SLIDE-level: BA=0.9167 | EMA smoothed=0.7419
#   Best model: epoch 5, BA=0.9167, loss=0.2704
#   Best EMA smoothed: 0.7917 (epoch 1)
#   Patience: 5/20 (remaining: 15)
#   LR: 0.000300
#
#  BEST MODEL at epoch 6 (reason: tied_slide_ba_better_loss)
#    slide_BA: 0.9167 | val_loss: 0.2373
# Iter 30, Fold 1, Epoch 6/100 | train_loss: 0.3976 | train_acc: 0.7761
#   PATCH-level: val_loss=0.2373, bal_acc=0.8976
#   SLIDE-level: BA=0.9167 | EMA smoothed=0.7944
#   Best model: epoch 6, BA=0.9167, loss=0.2373
#   Best EMA smoothed: 0.7917 (epoch 1)
#   Patience: 6/20 (remaining: 14)
#   LR: 0.000300
# Iter 30, Fold 1, Epoch 7/100 | train_loss: 0.3180 | train_acc: 0.7681
#   PATCH-level: val_loss=0.3087, bal_acc=0.9024
#   SLIDE-level: BA=0.9167 | EMA smoothed=0.8310
#   Best model: epoch 6, BA=0.9167, loss=0.2373
#   Best EMA smoothed: 0.8310 (epoch 7)
#   Patience: 0/20 (remaining: 20)
#   LR: 0.000300
# Iter 30, Fold 1, Epoch 8/100 | train_loss: 0.2567 | train_acc: 0.8439
#   PATCH-level: val_loss=0.4012, bal_acc=0.8827
#   SLIDE-level: BA=0.9167 | EMA smoothed=0.8567
#   Best model: epoch 6, BA=0.9167, loss=0.2373
#   Best EMA smoothed: 0.8567 (epoch 8)
#   Patience: 0/20 (remaining: 20)
#   LR: 0.000299
#
#  BEST MODEL at epoch 9 (reason: tied_slide_ba_better_loss)
#    slide_BA: 0.9167 | val_loss: 0.2086
# Iter 30, Fold 1, Epoch 9/100 | train_loss: 0.2796 | train_acc: 0.8340
#   PATCH-level: val_loss=0.2086, bal_acc=0.9188
#   SLIDE-level: BA=0.9167 | EMA smoothed=0.8747
#   Best model: epoch 9, BA=0.9167, loss=0.2086
#   Best EMA smoothed: 0.8747 (epoch 9)
#   Patience: 0/20 (remaining: 20)
#   LR: 0.000299
# Iter 30, Fold 1, Epoch 10/100 | train_loss: 0.3684 | train_acc: 0.7891
#   PATCH-level: val_loss=0.2794, bal_acc=0.9183
#   SLIDE-level: BA=0.9167 | EMA smoothed=0.8873
#   Best model: epoch 9, BA=0.9167, loss=0.2086
#   Best EMA smoothed: 0.8873 (epoch 10)
#   Patience: 0/20 (remaining: 20)
#   LR: 0.000298
# Iter 30, Fold 1, Epoch 11/100 | train_loss: 0.2405 | train_acc: 0.8528
#   PATCH-level: val_loss=0.2507, bal_acc=0.9058
#   SLIDE-level: BA=0.9167 | EMA smoothed=0.8961
#   Best model: epoch 9, BA=0.9167, loss=0.2086
#   Best EMA smoothed: 0.8873 (epoch 10)
#   Patience: 1/20 (remaining: 19)
#   LR: 0.000297
# Iter 30, Fold 1, Epoch 12/100 | train_loss: 0.2093 | train_acc: 0.8703
#   PATCH-level: val_loss=0.3033, bal_acc=0.9100
#   SLIDE-level: BA=0.9167 | EMA smoothed=0.9023
#   Best model: epoch 9, BA=0.9167, loss=0.2086
#   Best EMA smoothed: 0.9023 (epoch 12)
#   Patience: 0/20 (remaining: 20)
#   LR: 0.000296
# Iter 30, Fold 1, Epoch 13/100 | train_loss: 0.2746 | train_acc: 0.8080
#   PATCH-level: val_loss=0.4089, bal_acc=0.7660
#   SLIDE-level: BA=0.7500 | EMA smoothed=0.8566
#   Best model: epoch 9, BA=0.9167, loss=0.2086
#   Best EMA smoothed: 0.9023 (epoch 12)
#   Patience: 1/20 (remaining: 19)
#   LR: 0.000295
# Iter 30, Fold 1, Epoch 14/100 | train_loss: 0.3047 | train_acc: 0.8313
#   PATCH-level: val_loss=0.9632, bal_acc=0.6617
#   SLIDE-level: BA=0.5833 | EMA smoothed=0.7746
#   Best model: epoch 9, BA=0.9167, loss=0.2086
#   Best EMA smoothed: 0.9023 (epoch 12)
#   Patience: 2/20 (remaining: 18)
#   LR: 0.000293
# Iter 30, Fold 1, Epoch 15/100 | train_loss: 0.2567 | train_acc: 0.7972
#   PATCH-level: val_loss=0.5067, bal_acc=0.8667
#   SLIDE-level: BA=0.8333 | EMA smoothed=0.7922
#   Best model: epoch 9, BA=0.9167, loss=0.2086
#   Best EMA smoothed: 0.9023 (epoch 12)
#   Patience: 3/20 (remaining: 17)
#   LR: 0.000292
# Iter 30, Fold 1, Epoch 16/100 | train_loss: 0.2665 | train_acc: 0.8286
#   PATCH-level: val_loss=0.2565, bal_acc=0.9192
#   SLIDE-level: BA=0.9167 | EMA smoothed=0.8296
#   Best model: epoch 9, BA=0.9167, loss=0.2086
#   Best EMA smoothed: 0.9023 (epoch 12)
#   Patience: 4/20 (remaining: 16)
#   LR: 0.000290
# Iter 30, Fold 1, Epoch 17/100 | train_loss: 0.1992 | train_acc: 0.8394
#   PATCH-level: val_loss=0.2546, bal_acc=0.9088
#   SLIDE-level: BA=0.9167 | EMA smoothed=0.8557
#   Best model: epoch 9, BA=0.9167, loss=0.2086
#   Best EMA smoothed: 0.9023 (epoch 12)
#   Patience: 5/20 (remaining: 15)
#   LR: 0.000288
#
#  BEST MODEL at epoch 18 (reason: tied_slide_ba_better_loss)
#    slide_BA: 0.9167 | val_loss: 0.2005
# Iter 30, Fold 1, Epoch 18/100 | train_loss: 0.2304 | train_acc: 0.8223
#   PATCH-level: val_loss=0.2005, bal_acc=0.9171
#   SLIDE-level: BA=0.9167 | EMA smoothed=0.8740
#   Best model: epoch 18, BA=0.9167, loss=0.2005
#   Best EMA smoothed: 0.9023 (epoch 12)
#   Patience: 6/20 (remaining: 14)
#   LR: 0.000286
# Iter 30, Fold 1, Epoch 19/100 | train_loss: 0.1609 | train_acc: 0.8775
#   PATCH-level: val_loss=0.2962, bal_acc=0.9161
#   SLIDE-level: BA=0.9167 | EMA smoothed=0.8868
#   Best model: epoch 18, BA=0.9167, loss=0.2005
#   Best EMA smoothed: 0.9023 (epoch 12)
#   Patience: 7/20 (remaining: 13)
#   LR: 0.000284
# Iter 30, Fold 1, Epoch 20/100 | train_loss: 0.2392 | train_acc: 0.8564
#   PATCH-level: val_loss=0.2504, bal_acc=0.9249
#   SLIDE-level: BA=0.9167 | EMA smoothed=0.8958
#   Best model: epoch 18, BA=0.9167, loss=0.2005
#   Best EMA smoothed: 0.9023 (epoch 12)
#   Patience: 8/20 (remaining: 12)
#   LR: 0.000282
# Iter 30, Fold 1, Epoch 21/100 | train_loss: 0.2239 | train_acc: 0.8537
#   PATCH-level: val_loss=0.3524, bal_acc=0.9192
#   SLIDE-level: BA=0.9167 | EMA smoothed=0.9020
#   Best model: epoch 18, BA=0.9167, loss=0.2005
#   Best EMA smoothed: 0.9023 (epoch 12)
#   Patience: 9/20 (remaining: 11)
#   LR: 0.000280
# Iter 30, Fold 1, Epoch 22/100 | train_loss: 0.2398 | train_acc: 0.8717
#   PATCH-level: val_loss=0.4138, bal_acc=0.9019
#   SLIDE-level: BA=0.9167 | EMA smoothed=0.9064
#   Best model: epoch 18, BA=0.9167, loss=0.2005
#   Best EMA smoothed: 0.9023 (epoch 12)
#   Patience: 10/20 (remaining: 10)
#   LR: 0.000277
# Iter 30, Fold 1, Epoch 23/100 | train_loss: 0.2730 | train_acc: 0.8703
#   PATCH-level: val_loss=0.3571, bal_acc=0.9019
#   SLIDE-level: BA=0.9167 | EMA smoothed=0.9095
#   Best model: epoch 18, BA=0.9167, loss=0.2005
#   Best EMA smoothed: 0.9023 (epoch 12)
#   Patience: 11/20 (remaining: 9)
#   LR: 0.000274
# Iter 30, Fold 1, Epoch 24/100 | train_loss: 0.2063 | train_acc: 0.8461
#   PATCH-level: val_loss=0.2468, bal_acc=0.9217
#   SLIDE-level: BA=0.9167 | EMA smoothed=0.9116
#   Best model: epoch 18, BA=0.9167, loss=0.2005
#   Best EMA smoothed: 0.9023 (epoch 12)
#   Patience: 12/20 (remaining: 8)
#   LR: 0.000271
# Iter 30, Fold 1, Epoch 25/100 | train_loss: 0.2296 | train_acc: 0.8430
#   PATCH-level: val_loss=0.2897, bal_acc=0.9216
#   SLIDE-level: BA=0.9167 | EMA smoothed=0.9132
#   Best model: epoch 18, BA=0.9167, loss=0.2005
#   Best EMA smoothed: 0.9132 (epoch 25)
#   Patience: 0/20 (remaining: 20)
#   LR: 0.000268
# Checkpoint saved: cv_iter_29_fold_0_checkpoint.pth (best_epoch=17)[hash=2cbb5e7002e51df8]
# Iter 30, Fold 1, Epoch 26/100 | train_loss: 0.1846 | train_acc: 0.8188
#   PATCH-level: val_loss=1.0929, bal_acc=0.7358
#   SLIDE-level: BA=0.6667 | EMA smoothed=0.8392
#   Best model: epoch 18, BA=0.9167, loss=0.2005
#   Best EMA smoothed: 0.9132 (epoch 25)
#   Patience: 1/20 (remaining: 19)
#   LR: 0.000265
# Iter 30, Fold 1, Epoch 27/100 | train_loss: 0.2407 | train_acc: 0.7936
#   PATCH-level: val_loss=0.3314, bal_acc=0.9298
#   SLIDE-level: BA=0.9167 | EMA smoothed=0.8624
#   Best model: epoch 18, BA=0.9167, loss=0.2005
#   Best EMA smoothed: 0.9132 (epoch 25)
#   Patience: 2/20 (remaining: 18)
#   LR: 0.000262
# Iter 30, Fold 1, Epoch 28/100 | train_loss: 0.1772 | train_acc: 0.8228
#   PATCH-level: val_loss=0.3244, bal_acc=0.9259
#   SLIDE-level: BA=0.9167 | EMA smoothed=0.8787
#   Best model: epoch 18, BA=0.9167, loss=0.2005
#   Best EMA smoothed: 0.9132 (epoch 25)
#   Patience: 3/20 (remaining: 17)
#   LR: 0.000259
# Iter 30, Fold 1, Epoch 29/100 | train_loss: 0.2366 | train_acc: 0.8066
#   PATCH-level: val_loss=0.2322, bal_acc=0.9328
#   SLIDE-level: BA=0.9167 | EMA smoothed=0.8901
#   Best model: epoch 18, BA=0.9167, loss=0.2005
#   Best EMA smoothed: 0.9132 (epoch 25)
#   Patience: 4/20 (remaining: 16)
#   LR: 0.000255
#
# ...
#   Patience: 0/20 (remaining: 20)
#   LR: 0.000244
# Iter 30, Fold 5, Epoch 33/100 | train_loss: 0.1126 | train_acc: 0.9167
#   PATCH-level: val_loss=0.3972, bal_acc=0.8950
#   SLIDE-level: BA=0.9000 | EMA smoothed=0.8661
#   Best model: epoch 31, BA=0.9000, loss=0.3322
#   Best EMA smoothed: 0.8661 (epoch 33)
#   Patience: 0/20 (remaining: 20)
#   LR: 0.000240
# Iter 30, Fold 5, Epoch 34/100 | train_loss: 0.1602 | train_acc: 0.8494
#   PATCH-level: val_loss=1.0746, bal_acc=0.8217
#   SLIDE-level: BA=0.8000 | EMA smoothed=0.8463
#   Best model: epoch 31, BA=0.9000, loss=0.3322
#   Best EMA smoothed: 0.8661 (epoch 33)
#   Patience: 1/20 (remaining: 19)
#   LR: 0.000236
# Iter 30, Fold 5, Epoch 35/100 | train_loss: 0.1269 | train_acc: 0.8256
#   PATCH-level: val_loss=0.7604, bal_acc=0.8300
#   SLIDE-level: BA=0.8000 | EMA smoothed=0.8324
#   Best model: epoch 31, BA=0.9000, loss=0.3322
#   Best EMA smoothed: 0.8661 (epoch 33)
#   Patience: 2/20 (remaining: 18)
#   LR: 0.000232
# Iter 30, Fold 5, Epoch 36/100 | train_loss: 0.1282 | train_acc: 0.8741
#   PATCH-level: val_loss=1.4596, bal_acc=0.6939
#   SLIDE-level: BA=0.7000 | EMA smoothed=0.7927
#   Best model: epoch 31, BA=0.9000, loss=0.3322
#   Best EMA smoothed: 0.8661 (epoch 33)
#   Patience: 3/20 (remaining: 17)
#   LR: 0.000228
# Iter 30, Fold 5, Epoch 37/100 | train_loss: 0.1534 | train_acc: 0.8647
#   PATCH-level: val_loss=0.4250, bal_acc=0.8737
#   SLIDE-level: BA=0.8000 | EMA smoothed=0.7949
#   Best model: epoch 31, BA=0.9000, loss=0.3322
#   Best EMA smoothed: 0.8661 (epoch 33)
#   Patience: 4/20 (remaining: 16)
#   LR: 0.000224
# Iter 30, Fold 5, Epoch 38/100 | train_loss: 0.1819 | train_acc: 0.8706
#   PATCH-level: val_loss=0.3775, bal_acc=0.8754
#   SLIDE-level: BA=0.8000 | EMA smoothed=0.7964
#   Best model: epoch 31, BA=0.9000, loss=0.3322
#   Best EMA smoothed: 0.8661 (epoch 33)
#   Patience: 5/20 (remaining: 15)
#   LR: 0.000219
# Iter 30, Fold 5, Epoch 39/100 | train_loss: 0.1090 | train_acc: 0.8975
#   PATCH-level: val_loss=0.4019, bal_acc=0.8868
#   SLIDE-level: BA=0.9000 | EMA smoothed=0.8275
#   Best model: epoch 31, BA=0.9000, loss=0.3322
#   Best EMA smoothed: 0.8661 (epoch 33)
#   Patience: 6/20 (remaining: 14)
#   LR: 0.000215
# Iter 30, Fold 5, Epoch 40/100 | train_loss: 0.1296 | train_acc: 0.9237
#   PATCH-level: val_loss=0.4327, bal_acc=0.8655
#   SLIDE-level: BA=0.8000 | EMA smoothed=0.8192
#   Best model: epoch 31, BA=0.9000, loss=0.3322
#   Best EMA smoothed: 0.8661 (epoch 33)
#   Patience: 7/20 (remaining: 13)
#   LR: 0.000211
# Iter 30, Fold 5, Epoch 41/100 | train_loss: 0.0897 | train_acc: 0.8897
#   PATCH-level: val_loss=0.9805, bal_acc=0.8423
#   SLIDE-level: BA=0.8000 | EMA smoothed=0.8135
#   Best model: epoch 31, BA=0.9000, loss=0.3322
#   Best EMA smoothed: 0.8661 (epoch 33)
#   Patience: 8/20 (remaining: 12)
#   LR: 0.000206
# Iter 30, Fold 5, Epoch 42/100 | train_loss: 0.1309 | train_acc: 0.8459
#   PATCH-level: val_loss=0.3644, bal_acc=0.8819
#   SLIDE-level: BA=0.8000 | EMA smoothed=0.8094
#   Best model: epoch 31, BA=0.9000, loss=0.3322
#   Best EMA smoothed: 0.8661 (epoch 33)
#   Patience: 9/20 (remaining: 11)
#   LR: 0.000201
# Iter 30, Fold 5, Epoch 43/100 | train_loss: 0.1004 | train_acc: 0.8874
#   PATCH-level: val_loss=0.8209, bal_acc=0.8572
#   SLIDE-level: BA=0.8000 | EMA smoothed=0.8066
#   Best model: epoch 31, BA=0.9000, loss=0.3322
#   Best EMA smoothed: 0.8661 (epoch 33)
#   Patience: 10/20 (remaining: 10)
#   LR: 0.000197
# Iter 30, Fold 5, Epoch 44/100 | train_loss: 0.1550 | train_acc: 0.8956
#   PATCH-level: val_loss=0.8272, bal_acc=0.8539
#   SLIDE-level: BA=0.8000 | EMA smoothed=0.8046
#   Best model: epoch 31, BA=0.9000, loss=0.3322
#   Best EMA smoothed: 0.8661 (epoch 33)
#   Patience: 11/20 (remaining: 9)
#   LR: 0.000192
# Iter 30, Fold 5, Epoch 45/100 | train_loss: 0.1568 | train_acc: 0.8279
#   PATCH-level: val_loss=0.4948, bal_acc=0.8663
#   SLIDE-level: BA=0.8000 | EMA smoothed=0.8032
#   Best model: epoch 31, BA=0.9000, loss=0.3322
#   Best EMA smoothed: 0.8661 (epoch 33)
#   Patience: 12/20 (remaining: 8)
#   LR: 0.000187
# Iter 30, Fold 5, Epoch 46/100 | train_loss: 0.1549 | train_acc: 0.8197
#   PATCH-level: val_loss=0.7582, bal_acc=0.8539
#   SLIDE-level: BA=0.8000 | EMA smoothed=0.8023
#   Best model: epoch 31, BA=0.9000, loss=0.3322
#   Best EMA smoothed: 0.8661 (epoch 33)
#   Patience: 13/20 (remaining: 7)
#   LR: 0.000182
# Iter 30, Fold 5, Epoch 47/100 | train_loss: 0.0996 | train_acc: 0.8299
#   PATCH-level: val_loss=0.9644, bal_acc=0.8390
#   SLIDE-level: BA=0.8000 | EMA smoothed=0.8016
#   Best model: epoch 31, BA=0.9000, loss=0.3322
#   Best EMA smoothed: 0.8661 (epoch 33)
#   Patience: 14/20 (remaining: 6)
#   LR: 0.000178
# Iter 30, Fold 5, Epoch 48/100 | train_loss: 0.0956 | train_acc: 0.8819
#   PATCH-level: val_loss=1.4377, bal_acc=0.7574
#   SLIDE-level: BA=0.8000 | EMA smoothed=0.8011
#   Best model: epoch 31, BA=0.9000, loss=0.3322
#   Best EMA smoothed: 0.8661 (epoch 33)
#   Patience: 15/20 (remaining: 5)
#   LR: 0.000173
# Iter 30, Fold 5, Epoch 49/100 | train_loss: 0.0992 | train_acc: 0.9030
#   PATCH-level: val_loss=0.5912, bal_acc=0.8531
#   SLIDE-level: BA=0.8000 | EMA smoothed=0.8008
#   Best model: epoch 31, BA=0.9000, loss=0.3322
#   Best EMA smoothed: 0.8661 (epoch 33)
#   Patience: 16/20 (remaining: 4)
#   LR: 0.000168
# Iter 30, Fold 5, Epoch 50/100 | train_loss: 0.1821 | train_acc: 0.7943
#   PATCH-level: val_loss=0.4893, bal_acc=0.8556
#   SLIDE-level: BA=0.8000 | EMA smoothed=0.8005
#   Best model: epoch 31, BA=0.9000, loss=0.3322
#   Best EMA smoothed: 0.8661 (epoch 33)
#   Patience: 17/20 (remaining: 3)
#   LR: 0.000163
# Checkpoint saved: cv_iter_29_fold_4_checkpoint.pth (best_epoch=30)[hash=2cbb5e7002e51df8]
# Iter 30, Fold 5, Epoch 51/100 | train_loss: 0.1537 | train_acc: 0.8123
#   PATCH-level: val_loss=0.5511, bal_acc=0.8721
#   SLIDE-level: BA=0.8000 | EMA smoothed=0.8004
#   Best model: epoch 31, BA=0.9000, loss=0.3322
#   Best EMA smoothed: 0.8661 (epoch 33)
#   Patience: 18/20 (remaining: 2)
#   LR: 0.000158
# Iter 30, Fold 5, Epoch 52/100 | train_loss: 0.1351 | train_acc: 0.8827
#   PATCH-level: val_loss=0.4500, bal_acc=0.8679
#   SLIDE-level: BA=0.9000 | EMA smoothed=0.8303
#   Best model: epoch 31, BA=0.9000, loss=0.3322
#   Best EMA smoothed: 0.8661 (epoch 33)
#   Patience: 19/20 (remaining: 1)
#   LR: 0.000153
# Iter 30, Fold 5, Epoch 53/100 | train_loss: 0.0884 | train_acc: 0.8870
#   PATCH-level: val_loss=0.9248, bal_acc=0.8424
#   SLIDE-level: BA=0.8000 | EMA smoothed=0.8212
#   Best model: epoch 31, BA=0.9000, loss=0.3322
#   Best EMA smoothed: 0.8661 (epoch 33)
#   Patience: 20/20 (remaining: 0)
#   LR: 0.000148
# Checkpoint saved: cv_iter_29_fold_4_checkpoint.pth (best_epoch=30)[hash=2cbb5e7002e51df8]
#
#  EARLY STOPPING triggered at epoch 53
#    Best model: epoch 31
#    slide_BA=0.9000,    val_loss=0.3322
#    Best EMA smoothed: 0.8661 (epoch 33)
#
# RESTORED best model weights from epoch 31
#       1. slide_BA (maximize): 0.9000
#       2. val_loss (minimize): 0.3322
#     EMA smoothed at that epoch: 0.8309
#
# Saving FINAL checkpoint and history for Iter 30 Fold 5...
# Checkpoint saved: cv_iter_29_fold_4_checkpoint.pth (best_epoch=30)[hash=2cbb5e7002e51df8]
#
# Iter 30 Fold 5 Summary (at best epoch 31):
#   SLIDE-LEVEL:
#     Balanced Acc: 0.9000
#     Val Loss:     0.3322
#     EMA smoothed: 0.8309
#     MCC: 0.8000
#     AUC: 0.9500
#   PATCH-LEVEL:
#     Balanced Acc: 0.8859
#     MCC: 0.7695
#   Training time: 1395.95s
#   Cleaned local checkpoint: iter_29_fold_3
#   Cleaned Drive checkpoint: iter_29_fold_3
#
# ======================================================================
# CROSS-VALIDATION COMPLETE
# ======================================================================
#
# Completed 30 iterations × 5 folds
# Total fold summaries: 150
#
# Next phase: Analysis
# ======================================================================
#
# Loaded 150 fold summaries | iterations=30
# CV results saved to: /content/checkpoints/convtok/cv_results_convtok.csv
# Backed up to Drive: /content/drive/MyDrive/colab/conv_ViT/checkpoints/convtok/cv_results_convtok.csv
# /content/scripts/plotting_utils.py:112: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Metric", y="Mean Score", data=melted, palette="viridis", ax=ax)
# CV iteration distribution plot saved to: /content/drive/MyDrive/colab/conv_ViT/output/convtok/cv_iteration_results_convtok.png
# Determining optimal number of epochs...
#
# ======================================================================
# OPTIMAL EPOCHS CALCULATION (Hierarchically Correct)
# ======================================================================
# Input: 150 valid folds from 30 iterations
# Method: median
#
#   Raw value : 37.90 epochs
#
#  Train final model for 38 epochs
# ======================================================================
#
# Selected optimal_epochs: 38
#
#  Cleaned up 2 CV checkpoint(s) after analysis completion
# ----------------------------------------------------------------------
# PHASE: FINAL TRAINING
# ----------------------------------------------------------------------
# Training final model for 38 epochs
# Calculating normalization statistics on full training set...
# Final mean: [0.23691008985042572]
# Final std: [0.007409718818962574]
# Using uniform class weights (gamma=0, recommended with MixUp)
# MixUp enabled: alpha=0.2, prob=0.5
#
# ======================================================================
# FINAL MODEL TRAINING
#   Epochs      : 38
#   Model seed  : 42
#   Experiment  : convtok
# ======================================================================
#   Model config:
#     init_policy          : default
#     dim_head             : 64
#     pe_temperature       : 10000
#     convtok_hidden_ch    : 64
#     arch_hash            : 2cbb5e7002e51df8
# [ConvTok] Analytical output grid: (24, 24) (N=576) for 384×384 input
# [ConvTok] Analytical matched-N assertion passed at construction: (24, 24) = (24, 24), N=576
#   Model created (seed=42): 5,409,346 params (5,409,346 trainable)
#   [ConvTok diag] Token stats (post-ConvTok+LN, dummy batch): mean=0.0000, std=1.0000, grid=(24,24), N=576
# [ConvTok] Runtime token grid (forward #1): H'=24, W'=24, N=576
# [ConvTok] Matched-N assertion passed (forward #1): (24, 24) = (24, 24), N=576
# Final Epoch 1/38 | loss=0.6148 | acc=0.6378 | lr=0.000120
# Final Epoch 2/38 | loss=0.5528 | acc=0.6990 | lr=0.000180
# Final Epoch 3/38 | loss=0.4617 | acc=0.6979 | lr=0.000240
# Final Epoch 4/38 | loss=0.3995 | acc=0.7797 | lr=0.000300
# Final Epoch 5/38 | loss=0.4689 | acc=0.7148 | lr=0.000300
# Final Epoch 6/38 | loss=0.3035 | acc=0.7440 | lr=0.000299
# Final Epoch 7/38 | loss=0.3534 | acc=0.8175 | lr=0.000297
# Final Epoch 8/38 | loss=0.3017 | acc=0.8220 | lr=0.000294
# Final Epoch 9/38 | loss=0.2925 | acc=0.8148 | lr=0.000289
# Final Epoch 10/38 | loss=0.2103 | acc=0.8759 | lr=0.000283
# Final Epoch 11/38 | loss=0.2070 | acc=0.8595 | lr=0.000276
# Final Epoch 12/38 | loss=0.2737 | acc=0.7990 | lr=0.000268
# Final Epoch 13/38 | loss=0.2202 | acc=0.8498 | lr=0.000259
# Final Epoch 14/38 | loss=0.2248 | acc=0.8230 | lr=0.000248
# Final Epoch 15/38 | loss=0.2886 | acc=0.8763 | lr=0.000237
# Final Epoch 16/38 | loss=0.2390 | acc=0.8832 | lr=0.000225
# Final Epoch 17/38 | loss=0.1473 | acc=0.8632 | lr=0.000213
# Final Epoch 18/38 | loss=0.1840 | acc=0.8756 | lr=0.000199
# Final Epoch 19/38 | loss=0.2301 | acc=0.8017 | lr=0.000186
# Final Epoch 20/38 | loss=0.1834 | acc=0.8505 | lr=0.000172
# Final Epoch 21/38 | loss=0.1712 | acc=0.8423 | lr=0.000158
# Final Epoch 22/38 | loss=0.1869 | acc=0.8137 | lr=0.000143
# Final Epoch 23/38 | loss=0.2099 | acc=0.8306 | lr=0.000129
# Final Epoch 24/38 | loss=0.1345 | acc=0.8921 | lr=0.000115
# Final Epoch 25/38 | loss=0.1828 | acc=0.8914 | lr=0.000102
# Checkpoint saved: final_model_checkpoint.pth[hash=2cbb5e7002e51df8]
#   Backed up to Drive: final_model_checkpoint.pth
# Final Epoch 26/38 | loss=0.1387 | acc=0.8849 | lr=0.000088
# Final Epoch 27/38 | loss=0.1392 | acc=0.8804 | lr=0.000076
# Final Epoch 28/38 | loss=0.1275 | acc=0.8832 | lr=0.000064
# Final Epoch 29/38 | loss=0.1937 | acc=0.8326 | lr=0.000053
# Final Epoch 30/38 | loss=0.1325 | acc=0.8828 | lr=0.000042
# Final Epoch 31/38 | loss=0.1052 | acc=0.9120 | lr=0.000033
# Final Epoch 32/38 | loss=0.0799 | acc=0.8804 | lr=0.000025
# Final Epoch 33/38 | loss=0.1666 | acc=0.8213 | lr=0.000018
# Final Epoch 34/38 | loss=0.1301 | acc=0.8729 | lr=0.000012
# Final Epoch 35/38 | loss=0.0853 | acc=0.9034 | lr=0.000007
# Final Epoch 36/38 | loss=0.1215 | acc=0.8550 | lr=0.000004
# Final Epoch 37/38 | loss=0.0710 | acc=0.8990 | lr=0.000002
# Final Epoch 38/38 | loss=0.1161 | acc=0.8361 | lr=0.000001
# Checkpoint saved: final_model_checkpoint.pth[hash=2cbb5e7002e51df8]
#   Backed up to Drive: final_model_checkpoint.pth
# Final model saved to: /content/drive/MyDrive/colab/conv_ViT/output/convtok/final_model_convtok.pth
# Training curves saved to: /content/drive/MyDrive/colab/conv_ViT/output/convtok/final_model_training_curves_convtok.png
# ----------------------------------------------------------------------
# FINAL TRAINING COMPLETE
# ----------------------------------------------------------------------
#
# ======================================================================
# PHASE: TEST SET EVALUATION
# ======================================================================
#
#   Loading final model from final_model_convtok.pth
# [ConvTok] Analytical output grid: (24, 24) (N=576) for 384×384 input
# [ConvTok] Analytical matched-N assertion passed at construction: (24, 24) = (24, 24), N=576
#   Model loaded successfully
#   Running inference on 821 test samples...
# Testing:   0%|                                           | 0/13 [00:00<?, ?it/s]
# [ConvTok] Runtime token grid (forward #1): H'=24, W'=24, N=576
# [ConvTok] Matched-N assertion passed (forward #1): (24, 24) = (24, 24), N=576
#   Inference complete
#
#   Computing image-level metrics...
#   Calculating 95% confidence intervals (1000 bootstrap) - image level...
#
#   Aggregating predictions to slide level...
#   Aggregated 821 images into 12 slides
#   Calculating 95% confidence intervals (1000 bootstrap) - slide level...
#
#   Computing per-class metrics...
#
# ======================================================================
# TEST SET RESULTS SUMMARY
# ======================================================================
#
# IMAGE-LEVEL METRICS (Patch-based):
#   Balanced Accuracy: 0.9568 (95% CI: [0.8467, 0.9981])
#   MCC:               0.9115 (95% CI: [0.7113, 0.9973])
#   F1-Score:          0.9538 (95% CI: [0.8456, 0.9988])
#   AUC:               0.9947 (95% CI: [0.9699, 1.0000])
#
# SLIDE-LEVEL METRICS (Aggregated):
#   Balanced Accuracy: 0.9286 (95% CI: [0.7857, 1.0000])
#   MCC:               0.8452 (95% CI: [0.5292, 1.0000])
#   F1-Score:          0.9172 (95% CI: [0.7333, 1.0000])
#   AUC:               1.0000 (95% CI: [1.0000, 1.0000])
#
# PER-CLASS METRICS:
#
#   Candida albicans:
#     Image-level: P=1.000, R=0.914, F1=0.955 (n=440 images)
#     Slide-level: P=1.000, R=0.857, F1=0.923 (n=7 slides)
#
#   Candida glabrata:
#     Image-level: P=0.909, R=1.000, F1=0.953 (n=381 images)
#     Slide-level: P=0.833, R=1.000, F1=0.909 (n=5 slides)
# ======================================================================
#
#   Generating visualizations...
# Confusion matrix saved to: /content/drive/MyDrive/colab/conv_ViT/output/convtok/confusion_matrix_image_convtok.png
# Confusion matrix saved to: /content/drive/MyDrive/colab/conv_ViT/output/convtok/confusion_matrix_slide_convtok.png
# ROC/AUC curve plot saved to: /content/drive/MyDrive/colab/conv_ViT/output/convtok/roc_auc_curve_image_convtok.png
# ROC/AUC curve plot saved to: /content/drive/MyDrive/colab/conv_ViT/output/convtok/roc_auc_curve_slide_convtok.png
#
#   Results saved to: test_results_convtok.json
#
#  Cleaned up 150 fold history file(s)
#
# ======================================================================
# EVALUATION COMPLETE
# ======================================================================
#
# ----------------------------------------------------------------------
# PIPELINE COMPLETED SUCCESSFULLY
# ----------------------------------------------------------------------
# Experiment: convtok
# Results: /content/drive/MyDrive/colab/conv_ViT/output/convtok
